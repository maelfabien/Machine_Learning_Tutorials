# %% [markdown]
# <center><h1>Bag-Of-Words Embedding</center></h1>
# <center> Exploring TF and TF-IDF methods </center>

# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd
import re
from sklearn.feature_extraction.text import CountVectorizer
from nltk import wordpunct_tokenize, WordNetLemmatizer, sent_tokenize, pos_tag
from nltk.corpus import stopwords as sw, wordnet as wn
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import string

# %% [markdown]
# # BOW from scratch

# %% [markdown]
# We'll use South Park scripts as our database for messages : https://github.com/BobAdamsEE/SouthParkData

# %% [markdown]
# ### Preprocessing, split per sentence

# %%
def preprocess(document, max_features = 150, max_sentence_len = 300):
    """
    Returns a normalized, lemmatized list of tokens from a document by
    applying segmentation (breaking into sentences), then word/punctuation
    tokenization, and finally part of speech tagging. It uses the part of
    speech tags to look up the lemma in WordNet, and returns the lowercase
    version of all the words, removing stopwords and punctuation.
    """
    
    def lemmatize(token, tag):
        """
        Converts the tag to a WordNet POS tag, then uses that
        tag to perform an accurate WordNet lemmatization.
        """
        tag = {
        'N': wn.NOUN,
        'V': wn.VERB,
        'R': wn.ADV,
        'J': wn.ADJ
        }.get(tag[0], wn.NOUN)

        return WordNetLemmatizer().lemmatize(token, tag)

    def vectorize(doc, max_features, max_sentence_len):
        """
        Converts a document into a sequence of indices of length max_sentence_len retaining only max_features unique words
        """
        tokenizer = Tokenizer(num_words=max_features)
        tokenizer.fit_on_texts(doc)
        doc = tokenizer.texts_to_sequences(doc)
        doc_pad = pad_sequences(doc, padding = 'pre', truncating = 'pre', maxlen = max_sentence_len)
        return np.squeeze(doc_pad), tokenizer.word_index

    # Clean the text using a few regular expressions
    document = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", document)
    document = re.sub(r"what's", "what is ", document)
    document = re.sub(r"\'", " ", document)
    document = re.sub(r"@", " ", document)
    document = re.sub(r"\'ve", " have ", document)
    document = re.sub(r"can't", "cannot ", document)
    document = re.sub(r"n't", " not ", document)
    document = re.sub(r"i'm", "i am ", document)
    document = re.sub(r"\'re", " are ", document)
    document = re.sub(r"\'d", " would ", document)
    document = re.sub(r"\'ll", " will ", document)
    document = re.sub(r"(\d+)(k)", r"\g<1>000", document)
    document = document.replace("\n", " ")
    
    cleaned_document = []
    vocab = []
    
    # Break the document into sentences
    for sent in sent_tokenize(document):
        lemmatized_tokens = []

        # Break the sentence into part of speech tagged tokens
        for token, tag in pos_tag(wordpunct_tokenize(sent)):

            # Apply preprocessing to the tokens
            token = token.lower()
            token = token.strip()
            token = token.strip('_')
            token = token.strip('*')

            # If punctuation ignore token and continue
            if all(char in set(string.punctuation) for char in token): #token in set(sw.words('english')) or 
                continue

            # Lemmatize the token
            lemma = lemmatize(token, tag)
            lemmatized_tokens.append(lemma)
            vocab.append(lemma)
            
        cleaned_document.append(lemmatized_tokens)
    
    vocab = sorted(list(set(vocab)))
    
    return cleaned_document, vocab

# %% [markdown]
# ### Preprocessing, split per document

# %%
def preprocess(document, max_features = 150, max_sentence_len = 300):
    """
    Returns a normalized, lemmatized list of tokens from a document by
    applying segmentation (breaking into sentences), then word/punctuation
    tokenization, and finally part of speech tagging. It uses the part of
    speech tags to look up the lemma in WordNet, and returns the lowercase
    version of all the words, removing stopwords and punctuation.
    """
    
    def lemmatize(token, tag):
        """
        Converts the tag to a WordNet POS tag, then uses that
        tag to perform an accurate WordNet lemmatization.
        """
        tag = {
        'N': wn.NOUN,
        'V': wn.VERB,
        'R': wn.ADV,
        'J': wn.ADJ
        }.get(tag[0], wn.NOUN)

        return WordNetLemmatizer().lemmatize(token, tag)

    def vectorize(doc, max_features, max_sentence_len):
        """
        Converts a document into a sequence of indices of length max_sentence_len retaining only max_features unique words
        """
        tokenizer = Tokenizer(num_words=max_features)
        tokenizer.fit_on_texts(doc)
        doc = tokenizer.texts_to_sequences(doc)
        doc_pad = pad_sequences(doc, padding = 'pre', truncating = 'pre', maxlen = max_sentence_len)
        return np.squeeze(doc_pad), tokenizer.word_index
    
    cleaned_document = []
    vocab = []
    
    # Break the document into sentences
    for sent in document:
        
        # Clean the text using a few regular expressions
        sent = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", sent)
        sent = re.sub(r"what's", "what is ", sent)
        sent = re.sub(r"\'", " ", sent)
        sent = re.sub(r"@", " ", sent)
        sent = re.sub(r"\'ve", " have ", sent)
        sent = re.sub(r"can't", "cannot ", sent)
        sent = re.sub(r"n't", " not ", sent)
        sent = re.sub(r"i'm", "i am ", sent)
        sent = re.sub(r"\'re", " are ", sent)
        sent = re.sub(r"\'d", " would ", sent)
        sent = re.sub(r"\'ll", " will ", sent)
        sent = re.sub(r"(\d+)(k)", r"\g<1>000", sent)
        sent = sent.replace("\n", " ")
    
        lemmatized_tokens = []

        # Break the sentence into part of speech tagged tokens
        for token, tag in pos_tag(wordpunct_tokenize(sent)):

            # Apply preprocessing to the tokens
            token = token.lower()
            token = token.strip()
            token = token.strip('_')
            token = token.strip('*')

            # If punctuation ignore token and continue
            if all(char in set(string.punctuation) for char in token): #token in set(sw.words('english')) or 
                continue

            # Lemmatize the token
            lemma = lemmatize(token, tag)
            lemmatized_tokens.append(lemma)
            vocab.append(lemma)
            
        cleaned_document.append(lemmatized_tokens)
    
    vocab = sorted(list(set(vocab)))
    
    return cleaned_document, vocab

# %% [markdown]
# ### Apply it to the data

# %%
df = pd.read_csv('All-Seasons.csv')['Line'][:1000]
df.head()
# Out:
# 0           You guys, you guys! Chef is going away. \n
# 1                          Going away? For how long?\n
# 2                                           Forever.\n
# 3                                    I'm sorry boys.\n
# 4    Chef said he's been bored, so he joining a gro...
# Name: Line, dtype: object

# %%
df, vocab = preprocess(list(df))

# %% [markdown]
# ### Bag-Of-Words

# %%
def generate_bow(allsentences):    
    bag_vector = np.zeros((len(allsentences), len(vocab)))
    for j in range(len(allsentences)):
        for w in allsentences[j]:
            for i,word in enumerate(vocab):
                if word == w: 
                    bag_vector[j,i] += 1
    return bag_vector

# %%
bow = generate_bow(df)
bow.shape
# Out:
# (1000, 1589)

# %% [markdown]
# # BOW in Sk-learn

# %%
df = pd.read_csv('All-Seasons.csv')['Line'][:1000]

# %%
def preprocess(document, max_features = 150, max_sentence_len = 300):
    """
    Returns a normalized, lemmatized list of tokens from a document by
    applying segmentation (breaking into sentences), then word/punctuation
    tokenization, and finally part of speech tagging. It uses the part of
    speech tags to look up the lemma in WordNet, and returns the lowercase
    version of all the words, removing stopwords and punctuation.
    """
    
    def lemmatize(token, tag):
        """
        Converts the tag to a WordNet POS tag, then uses that
        tag to perform an accurate WordNet lemmatization.
        """
        tag = {
        'N': wn.NOUN,
        'V': wn.VERB,
        'R': wn.ADV,
        'J': wn.ADJ
        }.get(tag[0], wn.NOUN)

        return WordNetLemmatizer().lemmatize(token, tag)

    def vectorize(doc, max_features, max_sentence_len):
        """
        Converts a document into a sequence of indices of length max_sentence_len retaining only max_features unique words
        """
        tokenizer = Tokenizer(num_words=max_features)
        tokenizer.fit_on_texts(doc)
        doc = tokenizer.texts_to_sequences(doc)
        doc_pad = pad_sequences(doc, padding = 'pre', truncating = 'pre', maxlen = max_sentence_len)
        return np.squeeze(doc_pad), tokenizer.word_index

    cleaned_document = []
    vocab = []
    
    # Break the document into sentences
    for sent in document:
        
        lemmatized_tokens = []
        # Clean the text using a few regular expressions
        sent = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", sent)
        sent = re.sub(r"what's", "what is ", sent)
        sent = re.sub(r"\'", " ", sent)
        sent = re.sub(r"@", " ", sent)
        sent = re.sub(r"\'ve", " have ", sent)
        sent = re.sub(r"can't", "cannot ", sent)
        sent = re.sub(r"n't", " not ", sent)
        sent = re.sub(r"i'm", "i am ", sent)
        sent = re.sub(r"\'re", " are ", sent)
        sent = re.sub(r"\'d", " would ", sent)
        sent = re.sub(r"\'ll", " will ", sent)
        sent = re.sub(r"(\d+)(k)", r"\g<1>000", sent)
        sent = sent.replace("\n", " ")

        for token, tag in pos_tag(wordpunct_tokenize(sent)):

            # Apply preprocessing to the tokens
            token = token.lower()
            token = token.strip()
            token = token.strip('_')
            token = token.strip('*')

            # If punctuation ignore token and continue
            if all(char in set(string.punctuation) for char in token): #token in set(sw.words('english')) or 
                continue

            # Lemmatize the token
            lemma = lemmatize(token, tag)
            lemmatized_tokens.append(lemma)
            
        cleaned_document.append(' '.join(lemmatized_tokens))
    
    return cleaned_document

# %%
df = preprocess(list(df))

# %%
df
# Out:
# ['you guy you guy chef be go away',
#  'go away for how long',
#  'forever',
#  'i m sorry boy',
#  'chef say he s be bore so he join a group call the super adventure club',
#  'wow',
#  'chef what kind of question do you think adventure around the world be gonna answer',
#  'what s the meaning of life why be we here',
#  'i hope you re make the right choice',
#  'i m gonna miss him i m gonna miss chef and i and i don t know how to tell him',
#  'dude how be we gonna go on chef be our fuh f ffriend',
#  'and we will all miss you chef but we know you must do what your heart tell you',
#  'bye bye',
#  'good bye',
#  'so long',
#  'so long chef',
#  'good bye chef',
#  'good bye chef have a great time with the super adventure club',
#  'good bye',
#  'draw two card fatass',
#  'reverse to you jew',
#  'i ll get it',
#  'hello there child',
#  'he s back',
#  'yeah',
#  'all right',
#  'chef i can t believe you re back',
#  'well it s true',
#  'but be you back for good',
#  'that s right',
#  'hey everybody chef s back',
#  'what all right yeah',
#  'oh finally',
#  'wow it seem like you have a great time with the super adventure club chef they sound like really interesting people',
#  'yeah',
#  'but now that you re back here do that mean that you re not in the super adventure club anymore',
#  'nnono',
#  'ohhh so have you decide you can still belong to the super adventure club but live here in south park again',
#  'that s right',
#  'well it seem like the super adventure club be just what you need chef you must be feel very happy that you find a club to belong to with new friend but that you can also live here in south park with all your old friend whom you care for deeply right',
#  'that s right randy',
#  'well chef you re welcome to stay with me until you buy another house',
#  'thank you jimbo',
#  'well come on everybody i m sure chef would like a little time to get move back in',
#  'that s right thank you good bye everybody',
#  'later great to have you back bye bye see ya chef see you later bye bye',
#  'well i guess we ll see you in school tomorrow chef',
#  'you bet good bye child',
#  'right uh see ya',
#  'uh guy did chef seem a little uh trippy to you',
#  'well look he say he s happy now maybe he just need to rest up a little',
#  'yeah i m sure whatever that super adventure club do be pretty tire',
#  'yeah but whatever i m just glad he s back for good',
#  'yeah me too',
#  'it s really weird what he say i don t know it kind of confused me',
#  'oh boy oh boy i can t wait to have chef s lunch food again',
#  'yeah i hope he make his salisbury steak with buttered noodle',
#  'you guy you guy',
#  'what',
#  'something s wrong with chef he s say some really weird stuff',
#  'like what',
#  'i think i think he want to have sex with me',
#  'what',
#  'i gotta i gotta go',
#  'weirdo',
#  'hello there child',
#  'hey chef',
#  'how s it goin',
#  'good',
#  'well how about i meet you boys after work and we make love',
#  'excuse me',
#  'come on child you re my sexual fantasy let s all make sweet love',
#  'chef a be you okay',
#  'i want to stick my ball inside your rectum kyle',
#  'dude what be you say',
#  'i m gonna make love to your asshole child',
#  'what',
#  'hi kid i m detective jarvis i need to ask you all some difficult question about your school cafeteria chef',
#  'this doesn t make any sense',
#  'we have some information that all this time chef have be and still be a pedophile',
#  'no he s not',
#  'uh huh',
#  'no he s not',
#  'yeah yeah he be so',
#  'what s a pedophile',
#  'now we need some testimony in order to arrest chef so i m gonna use this doll to ask you kid a few question did chef ever touch any of you here',
#  'no',
#  'okay do he touch you here',
#  'no',
#  'did he ever do this how about this',
#  'my uncle bud do that to me once',
#  'did chef ever try one of these on for size',
#  'goddammit chef isn t like that something funny be go on around here',
#  'young man will you please pay attention this be very important stuff ohhh ohhhhhh',
#  'hello there child',
#  'chef the police be ask question about you',
#  'oh really well let s all go home and make love',
#  'no chef we don t wanna make love to you',
#  'kenny how would you like to sodomize my black as',
#  'chef chef you need to get out of here before you get arrest all right',
#  'i specialize in your asshole kyle',
#  'man i can t believe all this time chef just want u for sex',
#  'he didn t want u for sex fatass something be make him say those thing',
#  'like what',
#  'something must have happen to chef while he be go maybe he hit his head or or get stick in some quantum time vortex',
#  'well look he spend the last three month with that adventurer club maybe they know what happen to him',
#  'yeah i think',
#  'yeah',
#  'all right come on guy',
#  'hey you guy you know what they call a jewish woman s boobs jewbs',
#  'may i help you',
#  'ahh hi can we speak to the head guy or something',
#  'right this way',
#  'now the upper rim of kilimanjaro should be quite a trek and so we ll need to have a',
#  'excuse me sir these boy want to speak with you',
#  'ahh yes splendid good afternoon lads i m head adventurer william p connolly esquire welcome to the super adventure club',
#  'tally ho',
#  'indeed',
#  'uh hi our friend join your club a while back and now he want to molest kid',
#  'what well well yes of course that s what the super adventure club do',
#  'huh',
#  'we travel the world and have sex with child',
#  'yes what else would we do',
#  'well we think you go explore and like hunt and stuff',
#  'noo no that s the adventure club we re the super adventure club next week we ll be head to the out bank of the amazon where we will make camp and have sex with child of the ugani tribe then it s off to the mighty himalaya where we will climb k 2 and molest several tibetan child on the east summit',
#  'dude',
#  'i know but it get even good from there we will kayak to the fruitful bank of the mele river in africa where the secret and mysterious hanimi people have child who have never see a white man s erect penis of course we re always look for kid to have sex with on the plane rid over to these place so how would you all like to join the super adventure club',
#  'no',
#  'no oh really perhaps i should ask you again how would you like to join the super adventure club',
#  'no',
#  'dude what be you do',
#  'oh well it doesn t work on everybody well so long then',
#  'just what the hell be that thing',
#  'what what thing i don t see anything',
#  'ha i know it',
#  'knew what',
#  'the reason chef have be say those terrible thing about u be because he s be brainwash by this fruity little club',
#  'oh son of a bitch',
#  'come on child let s all go home and make love',
#  'you need to see a psychiatrist chef it s for your own good',
#  'i just like to make love up your butt',
#  'oh my god',
#  'mr chef be it',
#  'all right come on',
#  'hello i m dr neeland what can i do for you today',
#  'hi uh our friend have be brainwash by some fruity little club',
#  'brainwashed',
#  'yeah he join the super adventure club and they convince him have sex with child be okay with a little thing that go whrrrrrr',
#  'i think that club be for hiking and kayaking',
#  'no that s the adventure club the super adventure club have sex with child',
#  'oh oh that s right yeah',
#  'doctor do you have child',
#  'why yes i have two young boy',
#  'have you all be sodomize your child too',
#  'you say he s never be like this before',
#  'no chef have always be super cool',
#  'i m gonna make love to the child',
#  'he s pretty brainwash all right worst case i ve ever see',
#  'so what can we do',
#  'i m afraid there s no simple answer when somebody s brainwash it can take month even year to reverse the process',
#  'but we don t have year if chef keep this up he s gonna go to jail forever',
#  'tell me what be chef s favorite thing to do before it be have sex with child',
#  'have sex with woman',
#  'then that s it we d good get your friend to the peppermint hippo right away',
#  'all right guy be sure to tip the waitress this be two for one put your hand together this be monique',
#  'aw come on child let s go home',
#  'this isn t work',
#  'well let s give it some more time kid',
#  'would you like to daaance',
#  'no thanks we re try to unbrainwash our friend',
#  'daaance anybody wanna daaance',
#  'come on bitch dance',
#  'up yours fatty',
#  'bitch i ll twist your nut off',
#  'all right guy help me feel it out to them we get a featured dancer come out next put your hand together for spontaneous bootay',
#  'come on guy we might as well go',
#  'god damn',
#  'chef we re leave',
#  'nono wait let him go',
#  'come here chubby',
#  'wait a minute',
#  'he s remember',
#  'child what have i do',
#  'it s okay chef go on remember',
#  'i m goinna i m gonna',
#  'come on chef you can do it',
#  'i m gonna make love to you woman gonna lay you down by the fire',
#  'yay',
#  'chef',
#  'hey child everybody i m back ow',
#  'great shot william hit him with another',
#  'oh',
#  'chef',
#  'tally ho lads i must say you re start to become quite a thorn in my ball',
#  'where s chef what have you do with him',
#  'he s safe he s fast in the deprivation room and be read the super adventure club manual we ve get to undo the damage you ve do',
#  'look if you wanna go around the world molesting kid that s totally fine but why do you need chef',
#  'we don t need him he need u our club offer hope do you think we go around the world molest child just because it feel really really really really good no our club have a message and a secret that explain the mystery of life',
#  'oh jesus here we go',
#  'very well i m now go to tell you the secret of the super adventure club',
#  'we don t wanna hear it',
#  'you see the super adventure club be found by the great explorer of all time william p phinehas phinehas climb the high peak tame the mighty river but every time he get somewhere he realize that other explorer have beat him to it phinehas be depress until he realize that if he couldn t be the first to discover place he could be the first to have sex with the native child that inhabit those area phinehas quickly go down in history book a the first man to have sex with the aborigine child at uluru and the first explorer to bugger all the underage mountainfolk of nepal but now the most wonderful part you see after have sex with all those child phinehas realize that molest all those kid have make him immortal',
#  'immortal',
#  'he discover that child have thing call marlocks in their body and when an adult have sex with a child the marlocks implode feed the adult receptive cavity with energy that cause immortality so saith the ruler of bethos phinehas travel the world love many many child and he live for eternity until he be hit by a train in 1892',
#  'do you realize how retarded that sound',
#  'be it any more retarded than the idea of god send his son to die for our sin be it any more retarded than buddha sit beneath a tree for twenty year',
#  'yeah it s way way more retarded',
#  'well now that you know our club secret it appear you leave u no choice i m afraid we re go to have to ask you to leave',
#  'we re not leave without chef',
#  'if you choose not to leave then i m afraid we re just go to have to call security and make you leave you ll be let out by security and it will be super embarrassing and everyone here will see okay you know how like when you want people to leave but they win t leave it s really frustrating',
#  'we re not go anywhere without chef',
#  'cool people leave before they ve overstay their welcome you petulant fool you just have to push it didn t you you don t realize who you re deal with here security take these boy to the door',
#  'all right come on kid',
#  'no hey',
#  'haha look they re be lead out by security haha',
#  'no you don t understand they ve get our friend in the deprivation room',
#  'this be their house and they don t want you here',
#  'sorry dude but this fruity little club isn t take our friend',
#  'and sex with eskimo child require some special skill',
#  'chef come on',
#  'child',
#  'get out of here',
#  'kenny spin blossom nut squash',
#  'yeeeeehah',
#  'come on chef',
#  'i can t break these lock',
#  'here',
#  'run chef',
#  'what the impossible i make them leave',
#  'get outside',
#  'stop them',
#  'child run',
#  'stop',
#  'we make it',
#  'don t you remember why you leave south park in the first place',
#  'chef come on',
#  'you seek adventure and why do people seek adventure because their life have become dull and empty',
#  'yeah he want adventure not a bunch of ridiculous bullcrap right chef chef',
#  'don t forget all your training chef stay with u and your life will be grand and eternal',
#  'chef we love you',
#  'i m sorry child',
#  'no chef they ve fill your head with lie can t you see that',
#  'get the hell out of here child',
#  'yes look like our fruity little club be safe after all no',
#  'chef',
#  'ack ow oh ah oh dammit ah awww',
#  'no',
#  'a mountain lion',
#  'we can t lose another member shoot it',
#  'ah',
#  'all right this',
#  'chef',
#  'a grizzly bear',
#  'oh my god they kill chef',
#  'you bastards you bastards',
#  'pity he would have make an excellent child molester',
#  'maybe maybe he s still okay no really they say the last thing you do before you die be crap your',
#  'pooot',
#  'oh never mind',
#  'come on let s go',
#  'we re all here today because chef have be such an important part of our life a lot of u don t agree with the choice chef have make in the past few day some of u feel hurt and confuse that he seem to turn his back on u but we can t let the event of the last week take away the memory of how much chef make u smile i m gonna remember chef a the jolly old guy who always break into song i m gonna remember chef a the guy who give u advice to live by so you see we shouldn t be mad at chef for leave u we should be mad at that little fruity club for scramble his brain',
#  'yeah',
#  'he s right',
#  'and in the end i know that somewhere out there there s the good part of chef that s still alive in u all',
#  'be it work be it work',
#  'yes we ve get a pulse',
#  'get him in the icu suit hurry we have do it good raise him up chef can you hear me say something',
#  'hello there child how would you like some salisbury steak',
#  'yes go on',
#  'and for desert how would you child like to suck on my chocolate salty ball',
#  'oh you mean like a chocolate candy',
#  'no i mean my ball',
#  'yes yes hahahahahahaaa',
#  'hey there richard',
#  'oh hey gerald new car',
#  'yeah it s a hybrid i just i just couldn t sit back and be a part of destroy the earth anymore',
#  'well good for you',
#  'oho thanks',
#  'well there go the new high and mighty gerald broflovski',
#  'yeah ever since he get that new hybrid he think he s good than everyone else',
#  'you know the emission from a vehicle like yours cause irreparable damage to the ozone i drive a hybrid it s much good for the environment thanks',
#  'dad can we go home all you ever do since you get this car be drive around and show it off',
#  'hey be that a hybrid',
#  'oh yes you ve get one too i see',
#  'yeah i like to be a part of the solution and not part of the problem well anyway good for you',
#  'thanks',
#  'dad i think ike be starve to death',
#  'hold on boy we still have to go to the hardware store and hand out awareness citation to suv car in the parking lot',
#  'what',
#  'okay there s another one aw man look at that can you believe this an suv with a v8 engine make me sick ticket for drive a gas guzzler',
#  'dad can we go home please',
#  'look there s a jeep over there go write them a ticket kyle',
#  'but dad i want',
#  'now kyle',
#  'oh hey kyle',
#  'aw hey dude what be you do here',
#  'help my dad pick out some cool new power tool what be you do',
#  'help my dad give people fake ticket',
#  'what s this',
#  'oh sorry randy look like you get a ticket',
#  'a ticket failure to care about the environment oh goddammit do you do this gerald',
#  'yeah i m just you know try to make people more aware ya know it s a',
#  'you get some nerve you know that where do you come off ticket people',
#  'well randy calm down it s not a real ticket',
#  'i know it s not a real ticket',
#  'broflovski do you put this crap on my windshield',
#  'jimbo your truck probably get less than ten mile to the gallon',
#  'well thanks officer dickhole',
#  'dad let s just go',
#  'look i m just try to make the people of south park aware of a very serious problem',
#  'the problem gerald be that ever since you get a hybrid car you ve gotten so smug that you love the smell of your own fart',
#  'oh i m sorry i didn t think it be high and mighty to care about the earth',
#  'and that too stop talk with your eye close that s what smug people do',
#  'well i really don t see how that have anything to do with the',
#  'there like that stop that',
#  'who the hell put this faggy fake ticket on my truck',
#  'all right that do it come on kyle i don t want you hang around with these ignorant idiot',
#  'yeah yeah i think it s best we just do it right away',
#  'dad dad ike and i have be talk and well we feel that your new car be change you',
#  'yes it certainly be',
#  'we re think that a lot of people in town start too',
#  'take offense',
#  'a be start to take offense at your action we feel like you re start to become hmm',
#  'alienate',
#  'star start to become alienate from some of your friend',
#  'well i totally agree kyle',
#  'you do',
#  'yes a lot of people in town just aren t ready to drive hybrid car',
#  'righ okay good',
#  'and that s why i ve talk it over with your mother and we ve decide to move',
#  'what',
#  'we need to be where everyone be motivate and progressive like u start get your thing pack boys the broflovksi family be move to san francisco',
#  'yeah',
#  'uh hay stan uh you should come on over uh they re havin a goin away party for kyle',
#  'go away party what do you mean',
#  'well don t you know kyle s movin away',
#  'move away kyle can t move away',
#  'well he be',
#  'where s the go away party',
#  'at cartman s house',
#  'hey everybody there s more pop in the refrigerator let s make this the best go away party ever',
#  'hey eric where s kyle',
#  'who',
#  'kyle the person leave',
#  'kyle why would i invite kyle',
#  'dude a go away party be suppose to be for the person who be go away',
#  'kyle kyle',
#  'kyle s not here cartman didn t invite him',
#  'what',
#  'you guy this be our party that no good back stabbing jew rat be finally leave come on everyone let s sing nanana na nanana na hey hey hey goodbye kyle',
#  'kyle du what be go on',
#  'my dad say he can t live here anymore',
#  'mr broflovski please kyle s my best friend',
#  'i m sorry stan but unfortunately you live in a small minded town fill with ignorant boob',
#  'well maybe they ll change',
#  'i wouldn t count on it come on boy get in the car',
#  'nooo',
#  'maybe you can make a difference stan maybe you can get everyone to drive hybrid car until that day we re just gonna have to be with our own kind',
#  'i will i will get everyone to drive hybrid car i swear it',
#  'well what do you think huh',
#  'oh gerald it s beautiful',
#  'yeah now this be a house',
#  'oh hello there you must be the new neighbor',
#  'yes that s right we re the broflovskis',
#  'welcome to san francisco i m peter thompson this be my wife nancy jarvis and our son brian thompson jarvis so how do you like the neighborhood',
#  'oh it s gorgeous these old house be so neat',
#  'yes well unlike most city in san francisco we try to keep all the historic house instead of knock them down',
#  'you in here peter',
#  'oh hay paul come on in and meet the broflovskis',
#  'hello there i m paul mcdonahue this be my wife paulie beaumont mccallahan and our daughter mindy mcdonahue beaumont mccallahan',
#  'hello',
#  'we notice your hybrid out front that s a v series right',
#  'yeah that s right',
#  'whoa nice car but we re gonna have to get you into the bt series it emission be actually clean',
#  'wow so everyone here drive a hybrid huh',
#  'oh of course we re a little more progressive and ahead of the curve here in san francisco ahhhm anyway i m sure you ll find it much well here',
#  'yes you ll find that san francisco be pretty much more open mind and grow up than the midwest ahhh ahh ahh we re just a little bit more protective of our environment here in san francisco',
#  'yeah we sure be',
#  'come on people come on people now',
#  'dude what be you do',
#  'i m write a song about the importance of hybrid car so maybe people will change their way',
#  'that s gay heh',
#  'well if i have any chance of get kyle back i have to get people to stop drive suv',
#  'why do you want kyle back don t you see how awesome it be without him',
#  'you know cartman you may be stoke now but i bet you re gonna find that withuot kyle around to rip on your life be empty and hollow',
#  'psh whatever dude i don t need kyle to rip on i ve get butter come on butter you stupid jew',
#  'yeah i m a dumb jew',
#  'come on people come on people now',
#  'all right all you dreamer and creamer out there out there in south park i m gonna play a song by a local artist that really make me think about my impact on the earth this be stan marsh with hey people you ve gotta drive hybrid already',
#  'come on now people now people now people now come on now people now got to drive hybrid people now people now people now people now hybrid be for people now people now group of people drive people now get a hybrid be good people now',
#  'he s right',
#  'we have all get to be people now people drive hybrid people now people now people now hybrid now hybrid people drive people now come on people let s be people now hybrid people drive people now come on everybody be people now',
#  'yeah i just want to try to set an example you know',
#  'thanks',
#  'can you believe some people still don t drive hybrid',
#  'i know it s like earth to america hello this be simple stuff here gawl',
#  'well from now on i m only go to associate with other hybrid car driver everyone else be just ignorant m kay',
#  'good for you',
#  'thanks',
#  'at least we re smart enough to know good',
#  'thanks',
#  'come on everybody be people now',
#  'and so we be here to honor stan marsh for make south park the city with the high percentage of hybrid owner in the country',
#  'if only the rest of the country be as insightful a we be',
#  'ah thanks i be really just try to make it so my friend can move back here so if you don t mind i m gonna try to get a hold of him now',
#  'great speech',
#  'yeah well you know my son be just a little bit more clever than some',
#  'hello there i m ranger mcfriendly i m the person who watch over the delicate ecosystem of south park you must be the little boy who write that song',
#  'yeah',
#  'uhh',
#  'ow',
#  'you son of a bitch do you have any idea what you ve do',
#  'what',
#  'come with me',
#  'there look',
#  'smog there s never be smog over south park before',
#  'don t you get it when people drive hybrid car they get so full of themselves they spew ton of self satisfied garbage into the air that isn t smog it s smug',
#  'smug',
#  'hybrid car make good for emission level but people who drive hybrid car be the lead cause of smug you can have smug in the atmosphere and you know what that lead to glodal lam thanks to your gay little song south park be now the second smuggiest city in america',
#  'this be a south park news weather bulletin',
#  'it look like we have a smug alert here in south park our own keenan williams have the detail keenan',
#  'thanks tom a smug alert be in effect at least tomorrow morning all those hybrid car on the road have cause heavy smug to develop over most of park and jefferson county on the national map we can see smug over denver and develop smug in los angeles however san francisco be once again the smuggiest city in the country',
#  'a smuggy day in san francisco town',
#  'sheila do you meet gail and brian',
#  'no hello how be you',
#  'really good really good',
#  'hey there alan right',
#  'actually it s alain',
#  'right right w would would you like red or white wine',
#  'can i just get an empty glass',
#  'oh sure',
#  'can you believe all these imbecile in texas they just put another prisoner to death',
#  'so what do you do for fun',
#  'we drink and take drug',
#  'do you want some acid',
#  'oh no thanks we don t do that stuff',
#  'you will there s a reason most san francisco kid take a lot of drug',
#  'it s the only thing that allow u to deal with our parent all walk around love the smell of their own fart all the time',
#  'everything okay in here kyle',
#  'yeah fine dad',
#  'so much good here with the intellectual isn t it boys wuhh mmmm',
#  'well maybe i ll take just half a hit of acid',
#  'i want three',
#  'no no i m ask if there s a listing for broflovski in san francisco they just move there',
#  'haha take that jew boy i guess you heebs can t even play video football',
#  'yeah you re right',
#  'you know butter you make for a lousy jew',
#  'well i m sorry well it s just that i m not jewish and now th',
#  'no no don t apologize you asshole',
#  'marsh',
#  'oh crap ranger mcfriendly',
#  'who',
#  'you d good come with me to the news station our situation just get a lot bad',
#  'i notice it on the computer this morning look here this be the smug over south park it s get big and gain strength',
#  'the smug',
#  'the smug be get so massive that it s move west and fuse with the san francisco smug here these two smug cloud be combine fuel each other now take a look at this',
#  'what be that',
#  'it s the smug from george clooney s acceptance speech at the academy award',
#  'george clooney s acceptance speech',
#  'did you hear it he talk about how people in hollywood be ahead of the curve on social matte he even take credit for the civil right movement look the point be the smug from his acceptance speech have be slowly drift north since he give it and be head straight for the super cell the south park and san francisco smug be already at critical mass if it get hit by george clooney s acceptance speech it will be a disaster of epic proportion the perfect storm of self satisfaction',
#  'we ve get to tell the townspeople south park still have a chance to make it through the storm',
#  'what about san francisco',
#  'kid thanks to your gay little song there s not gonna be a san francisco',
#  'soo that s it people when the smug from george clooney s speech hit the san francisco and south park smug we re gonna witness a storm the like of which we ve never see',
#  'are you try to tell u the smug from our hybrid be actually gonna kill u all',
#  'if the smug cloud remain the way they be yes',
#  'this be all stan s fault he write that gay little song and get u to drive those damned hybrid',
#  'yeah good go stupid',
#  'listen though we all agree this be stan s fault there be still something we can do if we all work together to reduce smugness we might be able to lessen the effect of the storm at least here in our own town',
#  'then that s it there s only one way to reduce smugness we ve gotta destroy every hybrid car in town',
#  'everyone get your hybrid and meet at dawson s',
#  'hey where do you think you re go',
#  'i m gonna try and warn kyle to get out of san francisco',
#  'oh no you re not your gay little song get u to drive hybrid you re gonna help u get rid of em',
#  'how long do we have until the smug cloud collide',
#  'not long the smug from george clooney s academy award acceptance speech have already cross into arizona',
#  'the hell be that',
#  'wow eric you sure be a great guy for do this',
#  'i don t have a choice somebody have to get into san francisco and warn kyle s family to get out before the storm hit',
#  'but how come we can t just take the bus on into the city',
#  'you don t know san francisco butter it be the breeding ground for the hippie movement in the 60 those hard core liberal lesbian activist and die hard modern hippy young and old i swear i would never set foot in san francisco god help me all right butter i ll be tether to you through this cord it s my only lifeline so make sure it stay taut if you stop hear my voice for the love of christ start reel me in with all your strength',
#  'i will you re really great for go to warn kyle eric',
#  'i m not doin it for kyle i can t believe i m actually go to walk through san francisco well here it go',
#  'all right all right now get it into the masher hurry up',
#  'can t somebody else operate this i can t really reach',
#  'well then you shouldn t have write that gay little song shouldn t you have keenan we ve gotten rid of half the hybrid car how be the smug level',
#  'they re drop slowly but but we re run out of time',
#  'yeah it s like san francisco be more of a european city like paris or milan',
#  'butter be you there',
#  'i m here eric',
#  'i ve start to enter the smug i m about a quarter mile in can you give me an el',
#  'you must be near union square did you see a fountain to your left',
#  'yes it s just beyond yet another wine and cheese store',
#  'wait uhh eh take your next right you ve get to start head west',
#  'turn right at o two four niner',
#  'that s it that s that the last one',
#  'keenan keenan we ve smash the last hybrid',
#  'harry the smug from clooney s speech be about to hit the other smug system get everyone inside god help u',
#  'butter butter i think i m here 2419 castillo',
#  'that s it eric hurry somethin s goin on out here',
#  'mr broflovski mr broflovski there a smug storm we have to go',
#  'be smug be a good thing',
#  'oh my christ kyle kyle',
#  'the acid dude i m totally trip ball',
#  'i m totally trip ball i m totally trip ball',
#  'we have to get out of here now kyle kyle',
#  'and now the bad appear to be over last night s smug storm have leave thousand homeless all across the midwest people be pick up the piece city like denver and south park be heavily damage but still all right however san francisco i m afraid have disappear completely up it own asshole',
#  'no',
#  'i m sorry stan i m sorry your gay little song kill your friend',
#  'hey hey stan you re not gonna believe it you ve gotta come see',
#  'what',
#  'it s a miracle',
#  'kyle',
#  'hey stan',
#  'dude what happen',
#  'we don t know we be all pass out and next thing we know we just wake up on a bus heading here',
#  'it s like you have a guardian angel m kay',
#  'dude i m so glad you re not dead',
#  'so i guess there s nothing leave to do now but rebuild',
#  'yeah first off we re all gonna need new car',
#  'and let s make sure nobody get a stupid hybrid right',
#  'no hybrid car be a good thing',
#  'but hybrid car be the lead cause of smug m kay',
#  'hybrid car don t cause smugness people do look hybrid car be important they may even save our planet one day what you all need to do be just learn to drive hybrid and not be smug about it',
#  'you mean drive in hybrid but not act like we re good than everyone else because of it',
#  'yeah',
#  'i m i m not ready',
#  'i don t think i can do it either',
#  'it s simply ask too much',
#  'perhaps one day we can learn to drive hybrid without be smug about it but for now the technology be just too much for u',
#  'come on everybody let s go buy wasteful gas guzzler',
#  'well look like you re back for good huh kyle',
#  'yeah i guess so',
#  'we just can t get rid of you can we you sneaky jew rat',
#  'don t belittle my people you fuck fatass',
#  'ah that s good',
#  'but the bubble gum prince wasn t afraid he know that the land of chocolate be safe forever and ever goodnight my little angel',
#  'staaan',
#  'what what',
#  'get up get your shoe on gotta get out of here moove take this we ve gotta bring all the water we can shelly go get my gun',
#  'whats go on dad',
#  'just get the gun',
#  'unh come on',
#  'awwwgh',
#  'oh nooo',
#  'kyle what the hell be go on this time',
#  'i have no idea',
#  'take cover in the community center again',
#  'all right everyone get in and get a seal on that door',
#  'oh my god stephen we ve left butter',
#  'we can t go back out linda it s too late for him',
#  'dad dad what the hell be go on',
#  'a cartoon a cartoon be about to air on american television with with the muslim prophet mohammad a a character',
#  'sso',
#  'so stanley mohammad be sacred to the muslim people ever since those cartoon in denmark the rule have change nobody show an image of mohammad anymore',
#  'which cartoon be it what cartoon ll be so insensitive a to have mohammad a a character',
#  'who do you think the cartoon that s always push button with their careless toilet humor family guy',
#  'awww',
#  'how could family guy do that',
#  'why would family guy so blatantly insult muslim',
#  'because family guy doesn t care who they insult they only care about their precious money',
#  'oh come on people you really think anybody s gonna be that piss off about a cartoon',
#  'wu we ve get the tv working',
#  'once again a cartoon depict the muslim prophet mohammad be set to air tonight on family guy',
#  'oh randy hold me',
#  'the news have already spark a shockwave of protest throughout the muslim world all over the middle east muslim be burn american flag and family guy poster muslim terrorist al zawahri make this statement',
#  'we be so super piss off at family guy family guy isn t even that funny of a show a jihad on family guy and the family guy nation',
#  'so what happen now',
#  'we stay here through the night wait it out to see if they do anything if we re still alive in the morning then we ll know we re not dead',
#  'it s okay',
#  'we re alive we re alive',
#  'everyone everyone listen fox network censor the image of mohammad at the last minute',
#  'oh thank god',
#  'well it look like we ve dodge a bullet',
#  'they censor the image of mohammad how',
#  'i tivo every episode we can go to my house and see what they do',
#  'okay you guy check it out',
#  'you tivo every episode of family guy',
#  'dude it s a good show',
#  'yeah lot of people like family guy',
#  'yich',
#  'peter i can t believe you invite your old high school sweetheart over for dinner',
#  'you think that s bad remember when i audition to be david hasselhoff s car',
#  'hey there knight rider',
#  'after those bad guy kitt',
#  'yeah but dad why would you invite an ex girlfriend to dinner',
#  'perhaps he want to make our mother nervous',
#  'nervous like when i have to sell pancake to the school soccer captain',
#  'pancake for you captain',
#  'i ll be the captain and you ll be tenille',
#  'love will keep u together',
#  'hehaha heh',
#  'yich',
#  'but peter i don t wanna cook dinner for your ex girlfriend',
#  'well maybe we can just have tea',
#  'you mean like the time you have tea with mohammad the prophet of the muslim faith',
#  'come on mohammad let s get some tea',
#  'try my mr t tea',
#  'oh boy be that ever weird anyway i can t believe i invite my old sweetheart to dinner huh',
#  'that s it that s all they do',
#  'oh man that s not cool seriously that be not cool',
#  'what what s the big deal',
#  'what s the big deal you guy they just make fun of the religion of an entire group of people what you guy think that s okay do you care at all about people s feeling',
#  'since when you care about be sensitive to people s religion cartman',
#  'yeah you rip on people s religion all the time',
#  'that s different i m just a little boy that s a cartoon million of people watch it how would you feel kyle if there be a cartoon on television that make fun of jew all the time huh',
#  'uhhh',
#  'i m tell you guy it s wrong it s wrong it s wrong',
#  'kyle kyle what be you watchi',
#  'hey brian this be like the time i get a job a a carrot cake',
#  'gaaah it s family guy quick gerald do something',
#  'dad dad jesus christ',
#  'it s okay it s dead',
#  'you boys know you re not suppose to watch that careless show',
#  'mom it be nothing mohammad just stand there and then drink some tea',
#  'you boys don t understand anything it s obvious that you all need muslim sensitivity training',
#  'welcome to muslim sensitivity training it be important for u to understand why the muslim feel the way they do and why we can never show an image of mohammad',
#  'no muslim can t show an image of mohammad',
#  'kyle you re not be very sensitive',
#  'yeah kyle maybe you think this be funny but the rest of u don t',
#  'let s all look at why muslim be upset first of all in the muslim religion you re not allow to have what sex good there s no sex until marriage in the muslim world now this would be fine except that in the muslim religion you also can t anybody jack off okay jack it be strictly forbid in the muslim religion and what do we know about the place muslim live they live in good sand now put yourself in the shoe of a muslim it s friday night but you can t have sex and you can t jack off there s sand in your eye and probably in the crack of your as and then some cartoon come along from a country where people be get lay and mock your prophet well you know what i d be pretty piss off too',
#  'mr garrison that be ignorant and racist muslim be mad because of family guy not because they can t jack off right wendy',
#  'yeah',
#  'attention student proceed to the school gymnasium immediately for an emergency announcement',
#  'the hell s go on now',
#  'shh quiet student quiet',
#  'once again we have just learn that the family guy episode feature mohammad be only part 1 of a two parter and part 2 be go to air next week with mohammad uncensored',
#  'what',
#  'why would they',
#  'fox studio claim that the family guy write staff have demand the mohammad character be see in full view the head of fox have this to say',
#  'family guy be our big show if they insist we don t censor their work then we we can t',
#  'family guy i damn you to hell',
#  'once again bitter riot have start in the middle east this time even more massive and terrorist leader al zawahri have issue a threat',
#  'seriously family guy isn t even that well write the joke be all interchangeable and usually irrelevant to the plot when this episode air our retaliation will be massive',
#  'retaliation oh my god m kay',
#  'goddamned family guy now they re just provoke people it s like they want a holy war',
#  'do this mean we don t have school all week',
#  'you guy this be serious we have to do something',
#  'like what',
#  'we have to go to the fox network in l a we have to go and try to get that episode pull you guy with me',
#  'dude we can t go anywhere they ve shut down the airport and the bus',
#  'then we ll ride our big wheel',
#  'to los angeles',
#  'if that s what it take yes we have to talk to the network the family guy writer aren t gonna back down',
#  'well good for them they shouldn t the writer be stand up and say they aren t go to be intimidate',
#  'intimidate be that what you think this be about kyle',
#  'all right dude what the hell have get into you i don t trust for one second that your sudden concern for the muslim people be real',
#  'all right fine kyle forget the muslim faith for a minute people can get hurt if ten people die because family guy just have to have their little joke will you still think it s funny what if a hundred people die will it be funny then kyle i m go to los angeles i m gonna do whatever i can to get that episode pull before this get out of hand somebody have to speak for the muslim people somebody have to speak for what be right',
#  'kyle kyle wake up we have to go the terrorist be attack',
#  'dad are you sure there s time',
#  'this isn t a joke kyle bomb have already go off in six city',
#  'no',
#  'wait a minute where s ike',
#  'he be just here ike',
#  'ike',
#  'ike iiike ike',
#  'ice cream i want chocolate',
#  'ike this way iiike',
#  'kyyyle',
#  'nooooo',
#  'come to try and stop me it isn t gonna work',
#  'i didn t come to stop you i i think you re right cartman i want to help you get the family guy episode pull',
#  'yeah well i don t need a partner on this especially one who doesn t trust me',
#  'look cartman i don t know what be get into you but i i think it s pretty amazing and i think it s real you have to understand why i didn t believe you before',
#  'yeah i do understand kyle i ve be do the wrong thing for a long time do thing for my own selfish reason i just wanna do something right you know just this one time',
#  'it s a long trip dude you re gonna need help we can try and get the episode pull together',
#  'you know we might not even make it into the studio',
#  'i know but just like you i feel like i have to try people can really get hurt and a joke just isn t worth that',
#  'so what make you change your mind',
#  'i get some sound advice from an old friend',
#  'well kyle we d good get go',
#  'yeah',
#  'are you set',
#  'i m set let s do this',
#  'all right let s roll',
#  'people people quiet please we must not panic',
#  'well what be we gonna do mayor part 2 of the family guy episode air in six day',
#  'i believe that professor thomas from the university have come up with a solution',
#  'thank you mayor now look everyone muslim terrorist and extremist be threaten u for what family guy be go to do because they ve wrongly group u together our only hope be to make the muslim extremist know that we have no part in the mohammad episode that even though the episode air we didn t watch it we didn t hear it and we didn t talk about it',
#  'so how do we do that',
#  'we bury our head in sand we take twenty to twenty five dump truck fill them with sand from monarch lake and then dump the sand along south park avenue by use approximately eighteen dozen shovel we can each dig a hole in the sand stick our head in the hole and then have the person to our left bury them if we can manage to get every person s head bury deep deep in sand before the mohammad episode air we could avoid look like we re responsible for any part of this at all',
#  'no no wait a minute that s ridiculous what we need to do be just the opposite freedom of speech be at stake here don t you all see if anything we should all make cartoon of mohammad and show the terrorist and the extremist that we be all united in the belief that every person have a right to say what they want look people it s be real easy for u to stand up for free speech lately for the past few decade we haven t have to risk anything to defend it but those time be go to come and one of those time be right now and if we aren t willing to risk what we have then we just believe in free speech but we don t defend it',
#  'i like the sand idea',
#  'yeah me too',
#  'yeah the sand thing sound a lot simpler',
#  'we re gonna need eight dozen shovel and sixteen ton of sand let s move people',
#  'we get six day to make it to los angeles if we keep our stop to a minimum we should be able to get the episode pull just in time',
#  'yes and in just a few week from now family guy will be off the air forever',
#  'off the air but we re just go to try to get the mohammad episode pull',
#  'it s simple television economics kyle all it take to kill a show forever be get one episode pull if we convince the network to pull this episode for the sake of muslim then the catholic can demand a show they don t like get pull and then people with disability can demand another show get pull and so on and so on until family guy be no more it s exactly what happen to laverne shirley',
#  'whoa whoa wait a minute this isn t what i sign up for i like family guy why do we have to get it off the air forever',
#  'because they make f fun of muslim and and that s wrong',
#  'but that doesn t mean it have to go off the air you should like that show your sense of humor be just like family guy',
#  'don t you ever ever compare me to family guy you hear me kyle compare me to family guy again and so help me i will kill you where you stand',
#  'you unbelievable son of a bitch you never care about the muslim religion or the safety of people in america you just want family guy off the air',
#  'do you have any idea what it s like everywhere i go hey cartman you must like family guy right hey your sense of humor reminds me of family guy cartman i be nothing like family guy when i make joke they be inherent to a story deep situational and emotional joke base on what be relevant and have a point not just one interchangeable joke after another',
#  'what be you talk about',
#  'you don t understand',
#  'i can t believe i let you scare me into take your side you use fear to make me stop believe in free speech',
#  'well i guess you win t be help me now no biggie i don t need you to get the episode pull',
#  'no i be not let you go to that television studio and pretend to care about safety and sensitivity to get a show you don t like off the air',
#  'well then kyle i guess we oh my god be that tim mcgraw',
#  'what cartman',
#  'kyle stop it',
#  'holy crap',
#  'ahhh',
#  'stay on em jesus mary',
#  'if you have child be sure to bury their head in the sand before you bury your own',
#  'dad i don t wanna bury my head in the sand',
#  'it s the best say stanley did you eat your fruit roll up',
#  'yeah',
#  'all right make sure your snorkel be work all right now get your head in the hole',
#  'dad this be stupid',
#  'stanley there s no time for your immaturity do it all right sharon now do me',
#  'uh professor we all just think of somethin if everyone have their head bury by the person stand to their left then who s gonna bury the last person s head',
#  'yes i m afraid one person be go to have to be last and not have his head in the sand',
#  'i ll do it',
#  'dylan no',
#  'you realize by not bury your head in sand you ll appear to be a part of the family guy audience',
#  'yes i know',
#  'dylan please you can t',
#  'somebody have to do it sarah you run along now and you get your head in the sand i ll be all right you have to understand i m all she have',
#  'who be those people',
#  'no aaaah aaaah',
#  'hahahaha so long kyle',
#  'you son of a bitch i win t let you win you hear me',
#  'suck mah ball kyle',
#  'are you the network president',
#  'yes mr president',
#  'we need to discuss this family guy episode mr president',
#  'mr president my hand be tie the family guy writer insist i don t censor mohammad',
#  'but mr president this be a matter of national security they must be reason with',
#  'mr president there s something about the family guy write staff i think you should know',
#  'next week on south park the race continue cartman reach the family guy studio and learn the shocking secret behind the family guy write staff',
#  'this explain everything',
#  'a an entire nation bury it head in sand',
#  'the idea have sweep the nation but where will we find enough sand for everyone',
#  'and the battle between good and evil be finally wag',
#  'kyle quit it stop it kyle',
#  'will the cartoon be allow to appear uncensored will family guy be destroy will television executive fight for free speech or will comedy central puss out tune in to see part 2 of family guy next week on south park',
#  'previously on south park',
#  'the popular cartoon family guy be go to show the image of mohammad uncensored',
#  'if we all bury our head in sand we can avoid be any part of this',
#  'i m gonna do whatever i can to get that episode pull before this get out of hand',
#  'you just want family guy off the air',
#  'kyle stop it',
#  'so long kyle',
#  'you son of a bitch i win t let you win',
#  'mr president there s something about the family guy write staff i think you should know',
#  'and now the thrill conclusion of cartoon war will not be see tonight so that we can bring you this terrance phillip television special',
#  'say terrance isn t it wonderful have a holiday here at the lazy j ranch',
#  'it sure be phillip but i do believe this steer i m rid have the fart',
#  'oh look who s come isn t that mohammad the holy prophet of the muslim religion',
#  'hey guy how s it go',
#  'hello mohammad we ve read all aboat you in the koran',
#  'i m here to investigate a murder',
#  'all right just what the hell is going on here',
#  'you censor out the image of mohammad in our television special',
#  'ey you guy know the rule nobody can show the image of mohammad anymore it s dangerous',
#  'but you ruin the whole show',
#  'look i m not gonna risk the life of the people at this network let s just forget aboat it okay guy aw come on guy give me a break',
#  'we demand you rerun mystery at the lazy j ranch with mohammad uncensored',
#  'ey i run this network not you guy and if you ask me your show have become so preachy and full of message that you ve forget how to be funny no mohammad',
#  'but family guy be go to show mohammad on an episode that air tonight',
#  'i doubt it i ll bet that right now somebody be on their way to fox network to demand that that episode be pull',
#  'ma be i need to speak to the president of this network right away',
#  'what be it regard',
# ...
#  'o kay but if you ve get a problem with family guy you ll have to wait in line that little boy over there have an appointment to try and get family guy off the air altogether',
#  'dude can i go before you',
#  'eat my short',
#  'what the hell be go on hello excuse me i need to get to los angeles hello',
#  'starting in a small town in central colorado the idea have now spread all over america muslim continue to riot in the middle east demand that family guy not air tonight s episode amd muslim terrorist continue to make threat',
#  'family guy well not show mohammad tonight i m serious family guy isn t funny',
#  'osama bin laden have this to say',
#  'if you look closely at the writing in family guy you will see that the joke never derive from the plot and i think that s totally gay',
#  'bin laden go on to say that if family guy show the image of mohammad a plan the terrorist retaliation will be immediate',
#  'you one of them',
#  'who',
#  'how come your head ain t in the sand',
#  'so you don t like family guy either huh',
#  'i hate family guy',
#  'so what be your plan you re gonna ask the president of the network nicely to take it off the air',
#  'not nicely',
#  'look kid if you hate a tv show all you have to do be get an episode pull pretty soon the show be compromise and it go off the air',
#  'cool man',
#  'yes so my plan be to use this whole mohammad thing a a way to scare the network into pull tonight s show i m go to use fear to get them to do what i want',
#  'isn t that like terrorism',
#  'no it isn t like terrorism it be terrorism',
#  'i could do that',
#  'this be manipulation at it high lever you should let me handle this',
#  'i m a pretty bad kid',
#  'really what s the bad thing you ve ever do',
#  'i steal the head off a statue once',
#  'wow that s pretty hardcore geez that s like this one time when i didn t like a kid so i grind his parent up into chili and feed it to him',
#  'you get it man you get it',
#  'seeya',
#  'i want to assure the american people that a president i have exhaust every possible solution unfortunately mohammad will appear uncensored on family guy tonight at seven',
#  'mr president',
#  'mr president can t the writer of the show be reason with don t they know they re put the country in danger',
#  'i have come to understand something about the family guy write staff suffice it to say that they will not be persuade by the possibility of violence',
#  'mr president',
#  'what exactly do you learn about the family guy write staff mr president',
#  'i m afraid that information be classify',
#  'awww mr president',
#  'mr president can t you force the family guy write staff not to write anything about mohammad',
#  'couldn t you throw them in prison',
#  'look the fact of the matter be the family guy write staff be protect by something call the first amendment',
#  'and what exactly be this first amendment mr president',
#  'uh you know the right to free speech',
#  'awww',
#  'mr president when your administration come up with this first amendment do it not foresee a problem like this might happen',
#  'well we didn t come up with the first amendment it be already in place',
#  'what do you intend to do about this first amendment mr president',
#  'forgive me mr president but this first amendment sound like a lot of bureaucratic jibbery joob',
#  'yeah',
#  'that s right',
#  'okay let s discuss the fall lineup',
#  'sir there s still one little boy out here who want to speak with you about pull the family guy episode',
#  'all right let s get this over with',
#  'hello gentleman lady my name be little danny pocket and i win t take much of your time please excuse my tiny crutch it s the only way i can get around these day ow',
#  'oh poor kid',
#  'you see my father work for a newspaper in my native country of denmark his newspaper show an image of mohammad and two day later terrorist suicides bombed his building i be in the lobby when it happen first one terrorist suicide bomb u and then dozens more they just keep come suicide bomber run in the building and blow up one after another they be like mexican jumping bean i just don t wanna see people here at your studio get hurt because that would be of course your responsibility ow',
#  'i feel terrible it s so east to put terrorism out of mind until one of it victim be star you in the face',
#  'sir if we pull the episode the family guy write staff will refuse to work again',
#  'little boy will you talk to the family guy write staff if your story touch their heart like it have ours perhaps they ll back down from demand we air the episode',
#  'i ll certainly do my best ow',
#  'take this noble child over to the family guy office if he can scare them like he have u maybe we can pull the mohammad episode after all',
#  'yes and then family guy be as good a dead',
#  'what be that',
#  'i i say thank you thank you for listen',
#  'thanks a lot for the ride',
#  'ey it s the least i could do i hope you succeed kid i really don t wanna see family guy go off the air i love that show',
#  'i ll do everything i can',
#  'i mean i know it s just joke after joke but i like that at least it doesn t get all preachy and up it own as with message you know',
#  'excuse me do you know which way the network president s office be',
#  'who want to know',
#  'look my fat bastard friend be try to trick the network into get family guy off the air',
#  'the network president s office be in there',
#  'oh thanks dude',
#  'no problem man',
#  'hello this can t be right i ow',
#  'cowabunga motherfucker',
#  'hello mitchell',
#  'oh hi miss travis',
#  'the president have ask that little danny pocket here speak with the family guy write staff',
#  'are you sure they re work on a new episode right now',
#  'it win t take long sir ow',
#  'all right i ll take him back follow me little danny you must be excite not many people get to meet our write staff',
#  'yes i m totally excite family guy be so funny',
#  'well here we be danny the family guy write staff',
#  'wha what be they',
#  'they re manatee gretchen and flubber be from the gulf of mexico tinker pete and lucy be from the caribbean sea',
#  'family guy be write by manatee of course it all make sense now',
#  'they really be brilliant creature you see the right side of the tank be fill with idea ball each ball have a verb noun or pop culture reference write on it there s million of them the manatee choose an idea ball and swim it over to the joke combine on the other side of the tank uh there go gretchen she s comin up with an idea oh she come up with gary coleman the idea ball drop into the joke combine and form part of the new script laundry date winning mexico gary coleman a perfect family guy joke i can see it now',
#  'peter you didn t do the laundry today',
#  'you think that s bad remember the time i win a date to mexico with gary coleman',
#  'qu pasa se ore',
#  'whatchoo talkin bout willis',
#  'waitwaitaminute waitaminute these manatee demand that mohammad be show how manatee don t talk',
#  'when fox censor the image of mohammad last week it also mean that the mohammad ball have to come out of the idea tank it make the manatee very upset pull just one idea ball out of the idea tank and the manatee stop work he here i ll show you keith all right all right put it back in manatee be very ethical writer either everything s okay to write about or nothing be anyway the president of the network want you to speak with the manatee',
#  'oh yes yes um hello manatee i i think you should allow the network to pull your episode with mohammad see i m the victim of a a terrorist attack and terrorist might come after you if you',
#  'that isn t gonna work on them',
#  'why not',
#  'don t you know anything about manatee they re the only mammal that be completely unmoved by terrorst threat',
#  'son of a bitch',
#  'let me out of here kid why be you do this',
#  'well well well',
#  'cartman',
#  'hello kyle look like you ve run into a little snag in your plan as well',
#  'you fat sun of a bitch',
#  'you come so close to stop me didn t you kyle there be just one thing you didn t count on that more people besides me hate family guy',
#  'yeah',
#  'well a lot of people like family guy too who be you to decide it shouldn t be on the air',
#  'shut up you shut your fucking face man do it work did you scare the network into pull the episode',
#  'not yet but i ve come up with a new plan i ve learn how to make the family guy write staff stop working as soon a everyone go on their lunch break i can sneak back in',
#  'cool man',
#  'cartman let me out of this stupid net',
#  'good kyle that s good anger you re showin there see that that s emotional character development base on what be happen in the storyline not at all like family guy now if you ll excuse me kyle i ve get some idea ball to remove from a manatee tank',
#  'what',
#  'i don t understand it what s wrong with them',
#  'we don t know mr president they just stop work',
#  'but nobody take any idea ball out of the tank do they',
#  'no sir none of u do',
#  'then why be they refuse to write i agree to show mohammad uncensored i do what you ask what do you want from me',
#  'sir sir if you don t my say i think you ask for this you give in to the manatee last week now they know all they have to do be refuse to work and they can get whatever they want you spoil them by cave in now they thnk they can walk all over you sir you be in charge of this network not them maybe it s time you show them who s in charge',
#  'you re right it s time i stop let these primadonna manatee tell me what to do i m pull the mohammad episode you get that and if you all don t want to work tomorrow you can just find other job how long before family guy s suppose to air',
#  'twenty five minute',
#  'i gotta hurry',
#  'i do it i be god',
#  'family guy be go off the air no more family guy for me mon fr re',
#  'cartman you fuck fatass',
#  'how the hell do you get out',
#  'that kid and i have a long talk i tell him he be on a slippery slope to become a monster like you',
#  'aw god damnit you give him one of your gay little speech didn t you',
#  'you be not killing family guy',
#  'you re too late kyle the president of the network be pull the episode family guy be as good a dead',
#  'there s still time to tell the network president you re full of crap',
#  'i can t let you do that',
#  'get out of my way or i ll kick your as',
#  'fine kyle i guess it be inevitable let this be our final battle ow ow stop it kyle that s too hard ah ugh kyle stop it',
#  'ow quit it',
#  'ow quit it kyle bleh kyle',
#  'stop it',
#  'ow quit it',
#  'ow quit it kyle leh kyle let go okay okay come on time out kyle time out time out time out time in i d ow uh ah sh gah okay okay time out kyle t time out time out time out time out time out',
#  'no more timeouts fatass',
#  'time out time out time out kyle ay ay',
#  'kyle kyle get the get the kyle kyle dude that be that be in the ball dude serious seriously that be in the ball no hit no hitting in the ball kyle quit it kyle give it up kyle okay okay okay okay you win you win i give up hahaha i have my finger cross',
#  'thanks kid',
#  'network control this be the president i want you to pull the episode',
#  'what mr president be you sure',
#  'i m sure begin episode jettison sequence 0 2 900',
#  'abort system initiate',
#  'await confirmation',
#  'mr president we need your final approval code',
#  'president approval code 0 0 destruct',
#  'sir mister television executive stop',
#  'who be you',
#  'listen to me the little boy who convince you to pull the episode be a bastard child he only want you to pull it because he know it will be the end of family guy forever',
#  'the end of family guy',
#  'mr president we need final authorization',
#  'hold on julie what be you talk about kid',
#  'pull an episode because someone be offend start a chain reaction you ll have to pull more and more episode until the show go off the air completely it s what happen to laverne shirley',
#  'you mean the manatee aren t try to run the network',
#  'what manatees',
#  'go ahead mr president continue what you be do',
#  'no you have to show mohammad mr president',
#  'mr president we re await your order',
#  'sir just think about what you re do to free speech',
#  'no think about the people who could get hurt',
#  'ah i don t know who to listen to',
#  'okay i ll make it easy for you pull the mohammad episode now',
#  'okay i ll listen to you julie',
#  'noo wait you can t listen to him he s a lie deceitful monster who only want family guy off the air',
#  'but he have a gun',
#  'you can t do what he want just because he s the one threatening you with violence',
#  'shut up kyle',
#  'i can t be responsible for people get hurt especially me',
#  'yes people can get hurt that s how terrorism work but if you give into that doug you re allow terrorism to work do the right thing here',
#  'give the order to pull the episode mr president',
#  'i shouldn t even be in the office still it s suppose to be half day friday',
#  'mr president thirty second to airtime what do you want u to do',
#  'do the right thing mr president',
#  'how about i allow the episode to air but just censor out the image of mohammad again',
#  'i wish that be good enough but if you censor out mohammad then soon you ll have to censor out more',
#  'no gay speech kyle',
#  'if you don t show mohammad then you ve make a distinction what be okay to poke fun at and what isn t either it s all okay or none of it be',
#  'five second mr president',
#  'do the right thing show mohammad do the right thing',
#  'mr president we need a decision now',
#  'family guy go on air a plan uncensored',
#  'yes',
#  'no no i hate family guy',
#  'air it',
#  'peter you get a pink slip at work',
#  'you think that s bad remember the time i get a salmon helmet from mohammad while wear a toga',
#  'come mohammad',
#  'wow a salmon helmet thanks',
#  'anyway what be we talk about',
#  'oh yeah my pink slip',
#  'hey that wasn t bad at all they just show mohammad standin there lookin normal',
#  'mr president the terrorist be retaliate',
#  'what',
#  'or the time i',
#  'as soon a the image of mohammad appear terrorist leader al zawahri announce the retaliation',
#  'we warn you not to show mohammad but family guy do it anyways so now here be our retaliation on america',
#  'hello i be american',
#  'i m american too',
#  'we like to crap own each other',
#  'hello i be the president bush i will crap on both of you',
#  'ugh we love to crap',
#  'i m american i m pregnant with a baby but i m not marry',
#  'let s crap',
#  'look at me i m jesus would you like me to crap on you mr bush',
#  'mmm yummy yummy crap',
#  'oh yeah take that we burn you that wa way funnier than family guy',
#  'hi welcome to p f chang s how spicy would you like me to make your chang sauce',
#  'chris the people at table 3 need their check',
#  'i know i m swamp i ve get no help here',
#  'well what about the new waiter',
#  'the new waiter be useless and i think he s high',
#  'how spicy would you like your chang sauce',
#  'will you just place our order please',
#  'oh man i have no idea what be goin on',
#  'everything okay here',
#  'fine except this towel have be mix chang sauce for fifteen minute he s clueless',
#  'don t call me shoeless you re shoeless',
#  'yeah well you re a towel',
#  'you re a towel',
#  'all right that s it get out of here you re fire',
#  'yeah',
#  'not him you',
#  'awww',
#  'aw man i really screw up this time the rent s due at the end of the month and i don t have any money i need to shape up and find a new job quick but first maybe i ll get a little high wait here it go good idea comin yeah hey yeah i should become a writer if i just write a book about my life i can get it publish and then make plenty of money to pay rent',
#  'a million little fiber by toweleeeie this be a really good idea',
#  'aha mmm yes yes i see well that s quite a fascinating story you be engineer a a towel with a computer chip that determine dryness',
#  'yep and it s all true',
#  'chapter 4 through 8 however seem to all be about doritos brand corn chip',
#  'i guess i could edit those chapter down some']

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df)

# %%
print(X.toarray().shape)
# Out:
# (1000, 1818)

# %%
# Out:
# <1000x1818 sparse matrix of type '<class 'numpy.int64'>'
# 	with 10268 stored elements in Compressed Sparse Row format>
