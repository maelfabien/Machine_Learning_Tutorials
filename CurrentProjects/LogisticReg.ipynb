# %% [markdown]
# <center><h1> Logistic Regression </h1></center>
# <center> An illustration in Python </center>

# %% [markdown]
# # Import

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# # Sigmoid Function

# %% [markdown]
# ### Sigmoid

# %%
def sigmoid(x):
    a = []
    for item in x:
        a.append(1/(1+math.exp(-item)))
    return a

# %%
x = np.arange(-3., 3., 0.2)
sig = sigmoid(x)
z = logit(sig)

# %%
plt.figure(figsize=(12,8))

plt.plot(x,sig, label='sigmoid')
plt.plot(x,x, label='input')

plt.title("Sigmoid Function")
plt.legend()
plt.show()

# %% [markdown]
# ### Logit

# %%
def logit(x):
    a = []
    for item in x:
        a.append(math.log(item/(1-item)))
    return a

# %%
plt.figure(figsize=(12,8))

plt.plot(x,sig, label='sigmoid')
plt.plot(x,logit(sig), label='logit tranform')

plt.title("Sigmoid - Logit Function")
plt.legend()
plt.show()

# %%
#plt.axvline(0, color='red')
#plt.axhline(0.5, color='green')
