# %%
import numpy as np
import cv2
from skimage import data, filters
import matplotlib.pyplot as plt

# Open Video
cap = cv2.VideoCapture('road.mp4')
 
# Randomly select 25 frames
frameIds = cap.get(cv2.CAP_PROP_FRAME_COUNT) * np.random.uniform(size=25)
 
# Store selected frames in an array
frames = []
for fid in frameIds:
    cap.set(cv2.CAP_PROP_POS_FRAMES, fid)
    ret, frame = cap.read()
    frames.append(frame)

# Calculate the median along the time axis
medianFrame = np.median(frames, axis=0).astype(dtype=np.uint8)    
 
# Display median frame
plt.imshow(medianFrame)
plt.show()
#cv2.waitKey(0)

# %%
# Reset frame number to 0
cap.set(cv2.CAP_PROP_POS_FRAMES, 0)

# Convert background to grayscale
grayMedianFrame = cv2.cvtColor(medianFrame, cv2.COLOR_BGR2GRAY)
 
# Loop over all frames
ret = True

while(True):
 
    # Read frame
    ret, frame = cap.read()
    # Convert current frame to grayscale
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # Calculate absolute difference of current frame and 
    # the median frame
    dframe = cv2.absdiff(frame, grayMedianFrame)
    # Treshold to binarize
    th, dframe = cv2.threshold(dframe, 50, 255, cv2.THRESH_BINARY)

    w=100
    h=100
            
    contours, hier = cv2.findContours(dframe,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)
    for cnt in contours:
        if 300<cv2.contourArea(cnt):
            #cv2.drawContours(dframe,[cnt],0,(0,255,0),2)
            cv2.rectangle(dframe, (cnt[0][0][0], cnt[0][0][1]), (cnt[0][0][0]+w, cnt[0][0][1]+h), (0, 255, 0), 2)
    # Display image
    cv2.imshow('frame', dframe)
    cv2.waitKey(20)

# Release video object
cap.release()
 
# Destroy all windows
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-b050cef9d2d4> in <module>()
#      29     # Display image
#      30     cv2.imshow('frame', dframe)
# ---> 31     cv2.waitKey(20)
#      32
#      33 # Release video object
#
# KeyboardInterrupt:

# %%
contours, hier = cv2.findContours(dframe,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)
for cnt in contours:
    if 200<cv2.contourArea(cnt)<5000:
        cv2.drawContours(img,[cnt],0,(0,255,0),2)
        cv2.drawContours(mask,[cnt],0,255,-1)

# %%
from math import sqrt, pow 
from PIL import Image 
   
class DBSCAN:  
	
	visit_cnt = 0
	def __init__(self):  
		self.DB = [] #Database to represent RGB values
		self.epsilon = 0.3 #neighborhood distance for search  
		self.MinPts = 10  #minimum number of points required to form a cluster  
		self.cluster_inx = -1  
		self.cluster = []
		self.clusterCentroids = [] 
		self.noise = [] 
       
	def DBSCAN(self):  
		for i in range(len(self.DB)):  
			p_tmp = self.DB[i]  
			if (not p_tmp.visited):  
				p_tmp.visited = True 
				self.visit_cnt += 1 
				NeighborPts = self.epsilon_neighbourhood(p_tmp)  
				if(len(NeighborPts) < self.MinPts):  
					p_tmp.isnoise = True  
					self.noise.append(p_tmp)
					  
				else:  
					self.cluster.append([])  
					self.cluster_inx = self.cluster_inx + 1  
					self.check_neighbourhood(p_tmp, NeighborPts) 
    
	def check_neighbourhood(self, P, neighbor_points):  
		self.cluster[self.cluster_inx].append(P)  
		iterator = iter(neighbor_points)  
		while True:  
			try:   
				npoint_tmp = next(iterator)  
			except StopIteration:  
				break 
			if (not npoint_tmp.visited):  
				npoint_tmp.visited = True 
				self.visit_cnt += 1 
         
				NeighborPts1 = self.epsilon_neighbourhood(npoint_tmp)
				if (len(NeighborPts1) >= self.MinPts):  
					for j in range(len(NeighborPts1)):  
						neighbor_points.append(NeighborPts1[j])  
			if (not self.check_membership(npoint_tmp)):  
				self.cluster[self.cluster_inx].append(npoint_tmp)  
   
	def check_membership(self, P):  
		for i in range(len(self.cluster)):  
			for j in range(len(self.cluster[i])):  
				if (P.r == self.cluster[i][j].r and P.g == self.cluster[i][j].g and P.b == self.cluster[i][j].b):  
					return True  
		return False  
       
	def epsilon_neighbourhood(self, P):  
		pointInRegion = []  
		for i in range(len(self.DB)):  
			p_tmp = self.DB[i]
			if (self.dist(P, p_tmp) <= self.epsilon and P.r != p_tmp.r and P.g != p_tmp.g and P.b != p_tmp.b):  
				pointInRegion.append(p_tmp)  
		return pointInRegion #,points  
   
	def dist(self, p1, p2):  
		dr = (p1.r - p2.r)  
		dg = (p1.g - p2.g) 
		db = (p1.b - p2.b)
		a = sqrt(pow(dr,2) + pow(dg,2) + pow(db,2))
		return a/(255*sqrt(3))  
   
	def mode(self,x):
		tmp = []
		for i in x:
			tmp.append((i.r,i.g,i.b))
		return max(tmp,key = lambda x: tmp.count(x))	

class DataSet:  

	def __init__(self, rgb, x, y, visited = False, isnoise = False):  
		self.r = rgb[0]
		self.g = rgb[1]
		self.b = rgb[2] 
		self.x = x  
		self.y = y 
		self.visited = False  
		self.isnoise = False  
   
	def show(self):  
		return self.r, self.g, self.b

# %%
# read an image 
i = Image.open("car.png")
i = i.convert("RGB")  
width, height = i.size

cpixels = []
all_pixels = [] # list of tuples
for x in range(width):
    for y in range(height):
        cpixel = i.getpixel((x,y))
        cpixels.append(cpixel)
        all_pixels.append(DataSet(cpixel,x,y))

# %%
all_pixels
# Out:
# [<__main__.DataSet at 0x107276fd0>,
#  <__main__.DataSet at 0x107280048>,
#  <__main__.DataSet at 0x107280080>,
#  <__main__.DataSet at 0x1072800b8>,
#  <__main__.DataSet at 0x1072800f0>,
#  <__main__.DataSet at 0x107280128>,
#  <__main__.DataSet at 0x107280160>,
#  <__main__.DataSet at 0x107280198>,
#  <__main__.DataSet at 0x1072801d0>,
#  <__main__.DataSet at 0x107280208>,
#  <__main__.DataSet at 0x107280240>,
#  <__main__.DataSet at 0x107280278>,
#  <__main__.DataSet at 0x1072802b0>,
#  <__main__.DataSet at 0x1072802e8>,
#  <__main__.DataSet at 0x107280320>,
#  <__main__.DataSet at 0x107280358>,
#  <__main__.DataSet at 0x107280390>,
#  <__main__.DataSet at 0x1072803c8>,
#  <__main__.DataSet at 0x107280400>,
#  <__main__.DataSet at 0x107280438>,
#  <__main__.DataSet at 0x107280470>,
#  <__main__.DataSet at 0x1072804a8>,
#  <__main__.DataSet at 0x1072804e0>,
#  <__main__.DataSet at 0x107280518>,
#  <__main__.DataSet at 0x107280550>,
#  <__main__.DataSet at 0x107280588>,
#  <__main__.DataSet at 0x1072805c0>,
#  <__main__.DataSet at 0x1072805f8>,
#  <__main__.DataSet at 0x107280630>,
#  <__main__.DataSet at 0x107280668>,
#  <__main__.DataSet at 0x1072806a0>,
#  <__main__.DataSet at 0x1072806d8>,
#  <__main__.DataSet at 0x107280710>,
#  <__main__.DataSet at 0x107280748>,
#  <__main__.DataSet at 0x107280780>,
#  <__main__.DataSet at 0x1072807b8>,
#  <__main__.DataSet at 0x1072807f0>,
#  <__main__.DataSet at 0x107280828>,
#  <__main__.DataSet at 0x107280860>,
#  <__main__.DataSet at 0x107280898>,
#  <__main__.DataSet at 0x1072808d0>,
#  <__main__.DataSet at 0x107280908>,
#  <__main__.DataSet at 0x107280940>,
#  <__main__.DataSet at 0x107280978>,
#  <__main__.DataSet at 0x1072809b0>,
#  <__main__.DataSet at 0x1072809e8>,
#  <__main__.DataSet at 0x107280a20>,
#  <__main__.DataSet at 0x107280a58>,
#  <__main__.DataSet at 0x107280a90>,
#  <__main__.DataSet at 0x107280ac8>,
#  <__main__.DataSet at 0x107280b00>,
#  <__main__.DataSet at 0x107280b38>,
#  <__main__.DataSet at 0x107280b70>,
#  <__main__.DataSet at 0x107280ba8>,
#  <__main__.DataSet at 0x107280be0>,
#  <__main__.DataSet at 0x107280c18>,
#  <__main__.DataSet at 0x107280c50>,
#  <__main__.DataSet at 0x107280c88>,
#  <__main__.DataSet at 0x107280cc0>,
#  <__main__.DataSet at 0x107280cf8>,
#  <__main__.DataSet at 0x107280d30>,
#  <__main__.DataSet at 0x107280d68>,
#  <__main__.DataSet at 0x107280da0>,
#  <__main__.DataSet at 0x107280dd8>,
#  <__main__.DataSet at 0x107280e10>,
#  <__main__.DataSet at 0x107280e48>,
#  <__main__.DataSet at 0x107280e80>,
#  <__main__.DataSet at 0x107280eb8>,
#  <__main__.DataSet at 0x107280ef0>,
#  <__main__.DataSet at 0x107280f28>,
#  <__main__.DataSet at 0x107280f60>,
#  <__main__.DataSet at 0x107280f98>,
#  <__main__.DataSet at 0x107280fd0>,
#  <__main__.DataSet at 0x107285048>,
#  <__main__.DataSet at 0x107285080>,
#  <__main__.DataSet at 0x1072850b8>,
#  <__main__.DataSet at 0x1072850f0>,
#  <__main__.DataSet at 0x107285128>,
#  <__main__.DataSet at 0x107285160>,
#  <__main__.DataSet at 0x107285198>,
#  <__main__.DataSet at 0x1072851d0>,
#  <__main__.DataSet at 0x107285208>,
#  <__main__.DataSet at 0x107285240>,
#  <__main__.DataSet at 0x107285278>,
#  <__main__.DataSet at 0x1072852b0>,
#  <__main__.DataSet at 0x1072852e8>,
#  <__main__.DataSet at 0x107285320>,
#  <__main__.DataSet at 0x107285358>,
#  <__main__.DataSet at 0x107285390>,
#  <__main__.DataSet at 0x1072853c8>,
#  <__main__.DataSet at 0x107285400>,
#  <__main__.DataSet at 0x107285438>,
#  <__main__.DataSet at 0x107285470>,
#  <__main__.DataSet at 0x1072854a8>,
#  <__main__.DataSet at 0x1072854e0>,
#  <__main__.DataSet at 0x107285518>,
#  <__main__.DataSet at 0x107285550>,
#  <__main__.DataSet at 0x107285588>,
#  <__main__.DataSet at 0x1072855c0>,
#  <__main__.DataSet at 0x1072855f8>,
#  <__main__.DataSet at 0x107285630>,
#  <__main__.DataSet at 0x107285668>,
#  <__main__.DataSet at 0x1072856a0>,
#  <__main__.DataSet at 0x1072856d8>,
#  <__main__.DataSet at 0x107285710>,
#  <__main__.DataSet at 0x107285748>,
#  <__main__.DataSet at 0x107285780>,
#  <__main__.DataSet at 0x1072857b8>,
#  <__main__.DataSet at 0x1072857f0>,
#  <__main__.DataSet at 0x107285828>,
#  <__main__.DataSet at 0x107285860>,
#  <__main__.DataSet at 0x107285898>,
#  <__main__.DataSet at 0x1072858d0>,
#  <__main__.DataSet at 0x107285908>,
#  <__main__.DataSet at 0x107285940>,
#  <__main__.DataSet at 0x107285978>,
#  <__main__.DataSet at 0x1072859b0>,
#  <__main__.DataSet at 0x1072859e8>,
#  <__main__.DataSet at 0x107285a20>,
#  <__main__.DataSet at 0x107285a58>,
#  <__main__.DataSet at 0x107285a90>,
#  <__main__.DataSet at 0x107285ac8>,
#  <__main__.DataSet at 0x107285b00>,
#  <__main__.DataSet at 0x107285b38>,
#  <__main__.DataSet at 0x107285b70>,
#  <__main__.DataSet at 0x107285ba8>,
#  <__main__.DataSet at 0x107285be0>,
#  <__main__.DataSet at 0x107285c18>,
#  <__main__.DataSet at 0x107285c50>,
#  <__main__.DataSet at 0x107285c88>,
#  <__main__.DataSet at 0x107285cc0>,
#  <__main__.DataSet at 0x107285cf8>,
#  <__main__.DataSet at 0x107285d30>,
#  <__main__.DataSet at 0x107285d68>,
#  <__main__.DataSet at 0x107285da0>,
#  <__main__.DataSet at 0x107285dd8>,
#  <__main__.DataSet at 0x107285e10>,
#  <__main__.DataSet at 0x107285e48>,
#  <__main__.DataSet at 0x107285e80>,
#  <__main__.DataSet at 0x107285eb8>,
#  <__main__.DataSet at 0x107285ef0>,
#  <__main__.DataSet at 0x107285f28>,
#  <__main__.DataSet at 0x107285f60>,
#  <__main__.DataSet at 0x107285f98>,
#  <__main__.DataSet at 0x107285fd0>,
#  <__main__.DataSet at 0x10728a048>,
#  <__main__.DataSet at 0x10728a080>,
#  <__main__.DataSet at 0x10728a0b8>,
#  <__main__.DataSet at 0x10728a0f0>,
#  <__main__.DataSet at 0x10728a128>,
#  <__main__.DataSet at 0x10728a160>,
#  <__main__.DataSet at 0x10728a198>,
#  <__main__.DataSet at 0x10728a1d0>,
#  <__main__.DataSet at 0x10728a208>,
#  <__main__.DataSet at 0x10728a240>,
#  <__main__.DataSet at 0x10728a278>,
#  <__main__.DataSet at 0x10728a2b0>,
#  <__main__.DataSet at 0x10728a2e8>,
#  <__main__.DataSet at 0x10728a320>,
#  <__main__.DataSet at 0x10728a358>,
#  <__main__.DataSet at 0x10728a390>,
#  <__main__.DataSet at 0x10728a3c8>,
#  <__main__.DataSet at 0x10728a400>,
#  <__main__.DataSet at 0x10728a438>,
#  <__main__.DataSet at 0x10728a470>,
#  <__main__.DataSet at 0x10728a4a8>,
#  <__main__.DataSet at 0x10728a4e0>,
#  <__main__.DataSet at 0x10728a518>,
#  <__main__.DataSet at 0x10728a550>,
#  <__main__.DataSet at 0x10728a588>,
#  <__main__.DataSet at 0x10728a5c0>,
#  <__main__.DataSet at 0x10728a5f8>,
#  <__main__.DataSet at 0x10728a630>,
#  <__main__.DataSet at 0x10728a668>,
#  <__main__.DataSet at 0x10728a6a0>,
#  <__main__.DataSet at 0x10728a6d8>,
#  <__main__.DataSet at 0x10728a710>,
#  <__main__.DataSet at 0x10728a748>,
#  <__main__.DataSet at 0x10728a780>,
#  <__main__.DataSet at 0x10728a7b8>,
#  <__main__.DataSet at 0x10728a7f0>,
#  <__main__.DataSet at 0x10728a828>,
#  <__main__.DataSet at 0x10728a860>,
#  <__main__.DataSet at 0x10728a898>,
#  <__main__.DataSet at 0x10728a8d0>,
#  <__main__.DataSet at 0x10728a908>,
#  <__main__.DataSet at 0x10728a940>,
#  <__main__.DataSet at 0x10728a978>,
#  <__main__.DataSet at 0x10728a9b0>,
#  <__main__.DataSet at 0x10728a9e8>,
#  <__main__.DataSet at 0x10728aa20>,
#  <__main__.DataSet at 0x10728aa58>,
#  <__main__.DataSet at 0x10728aa90>,
#  <__main__.DataSet at 0x10728aac8>,
#  <__main__.DataSet at 0x10728ab00>,
#  <__main__.DataSet at 0x10728ab38>,
#  <__main__.DataSet at 0x10728ab70>,
#  <__main__.DataSet at 0x10728aba8>,
#  <__main__.DataSet at 0x10728abe0>,
#  <__main__.DataSet at 0x10728ac18>,
#  <__main__.DataSet at 0x10728ac50>,
#  <__main__.DataSet at 0x10728ac88>,
#  <__main__.DataSet at 0x10728acc0>,
#  <__main__.DataSet at 0x10728acf8>,
#  <__main__.DataSet at 0x10728ad30>,
#  <__main__.DataSet at 0x10728ad68>,
#  <__main__.DataSet at 0x10728ada0>,
#  <__main__.DataSet at 0x10728add8>,
#  <__main__.DataSet at 0x10728ae10>,
#  <__main__.DataSet at 0x10728ae48>,
#  <__main__.DataSet at 0x10728ae80>,
#  <__main__.DataSet at 0x10728aeb8>,
#  <__main__.DataSet at 0x10728aef0>,
#  <__main__.DataSet at 0x10728af28>,
#  <__main__.DataSet at 0x10728af60>,
#  <__main__.DataSet at 0x10728af98>,
#  <__main__.DataSet at 0x10728afd0>,
#  <__main__.DataSet at 0x1072e7048>,
#  <__main__.DataSet at 0x1072e7080>,
#  <__main__.DataSet at 0x1072e70b8>,
#  <__main__.DataSet at 0x1072e70f0>,
#  <__main__.DataSet at 0x1072e7128>,
#  <__main__.DataSet at 0x1072e7160>,
#  <__main__.DataSet at 0x1072e7198>,
#  <__main__.DataSet at 0x1072e71d0>,
#  <__main__.DataSet at 0x1072e7208>,
#  <__main__.DataSet at 0x1072e7240>,
#  <__main__.DataSet at 0x1072e7278>,
#  <__main__.DataSet at 0x1072e72b0>,
#  <__main__.DataSet at 0x1072e72e8>,
#  <__main__.DataSet at 0x1072e7320>,
#  <__main__.DataSet at 0x1072e7358>,
#  <__main__.DataSet at 0x1072e7390>,
#  <__main__.DataSet at 0x1072e73c8>,
#  <__main__.DataSet at 0x1072e7400>,
#  <__main__.DataSet at 0x1072e7438>,
#  <__main__.DataSet at 0x1072e7470>,
#  <__main__.DataSet at 0x1072e74a8>,
#  <__main__.DataSet at 0x1072e74e0>,
#  <__main__.DataSet at 0x1072e7518>,
#  <__main__.DataSet at 0x1072e7550>,
#  <__main__.DataSet at 0x1072e7588>,
#  <__main__.DataSet at 0x1072e75c0>,
#  <__main__.DataSet at 0x1072e75f8>,
#  <__main__.DataSet at 0x1072e7630>,
#  <__main__.DataSet at 0x1072e7668>,
#  <__main__.DataSet at 0x1072e76a0>,
#  <__main__.DataSet at 0x1072e76d8>,
#  <__main__.DataSet at 0x1072e7710>,
#  <__main__.DataSet at 0x1072e7748>,
#  <__main__.DataSet at 0x1072e7780>,
#  <__main__.DataSet at 0x1072e77b8>,
#  <__main__.DataSet at 0x1072e77f0>,
#  <__main__.DataSet at 0x1072e7828>,
#  <__main__.DataSet at 0x1072e7860>,
#  <__main__.DataSet at 0x1072e7898>,
#  <__main__.DataSet at 0x1072e78d0>,
#  <__main__.DataSet at 0x1072e7908>,
#  <__main__.DataSet at 0x1072e7940>,
#  <__main__.DataSet at 0x1072e7978>,
#  <__main__.DataSet at 0x1072e79b0>,
#  <__main__.DataSet at 0x1072e79e8>,
#  <__main__.DataSet at 0x1072e7a20>,
#  <__main__.DataSet at 0x1072e7a58>,
#  <__main__.DataSet at 0x1072e7a90>,
#  <__main__.DataSet at 0x1072e7ac8>,
#  <__main__.DataSet at 0x1072e7b00>,
#  <__main__.DataSet at 0x1072e7b38>,
#  <__main__.DataSet at 0x1072e7b70>,
#  <__main__.DataSet at 0x1072e7ba8>,
#  <__main__.DataSet at 0x1072e7be0>,
#  <__main__.DataSet at 0x1072e7c18>,
#  <__main__.DataSet at 0x1072e7c50>,
#  <__main__.DataSet at 0x1072e7c88>,
#  <__main__.DataSet at 0x1072e7cc0>,
#  <__main__.DataSet at 0x1072e7cf8>,
#  <__main__.DataSet at 0x1072e7d30>,
#  <__main__.DataSet at 0x1072e7d68>,
#  <__main__.DataSet at 0x1072e7da0>,
#  <__main__.DataSet at 0x1072e7dd8>,
#  <__main__.DataSet at 0x1072e7e10>,
#  <__main__.DataSet at 0x1072e7e48>,
#  <__main__.DataSet at 0x1072e7e80>,
#  <__main__.DataSet at 0x1072e7eb8>,
#  <__main__.DataSet at 0x1072e7ef0>,
#  <__main__.DataSet at 0x1072e7f28>,
#  <__main__.DataSet at 0x1072e7f60>,
#  <__main__.DataSet at 0x1072e7f98>,
#  <__main__.DataSet at 0x1072e7fd0>,
#  <__main__.DataSet at 0x1072ec048>,
#  <__main__.DataSet at 0x1072ec080>,
#  <__main__.DataSet at 0x1072ec0b8>,
#  <__main__.DataSet at 0x1072ec0f0>,
#  <__main__.DataSet at 0x1072ec128>,
#  <__main__.DataSet at 0x1072ec160>,
#  <__main__.DataSet at 0x1072ec198>,
#  <__main__.DataSet at 0x1072ec1d0>,
#  <__main__.DataSet at 0x1072ec208>,
#  <__main__.DataSet at 0x1072ec240>,
#  <__main__.DataSet at 0x1072ec278>,
#  <__main__.DataSet at 0x1072ec2b0>,
#  <__main__.DataSet at 0x1072ec2e8>,
#  <__main__.DataSet at 0x1072ec320>,
#  <__main__.DataSet at 0x1072ec358>,
#  <__main__.DataSet at 0x1072ec390>,
#  <__main__.DataSet at 0x1072ec3c8>,
#  <__main__.DataSet at 0x1072ec400>,
#  <__main__.DataSet at 0x1072ec438>,
#  <__main__.DataSet at 0x1072ec470>,
#  <__main__.DataSet at 0x1072ec4a8>,
#  <__main__.DataSet at 0x1072ec4e0>,
#  <__main__.DataSet at 0x1072ec518>,
#  <__main__.DataSet at 0x1072ec550>,
#  <__main__.DataSet at 0x1072ec588>,
#  <__main__.DataSet at 0x1072ec5c0>,
#  <__main__.DataSet at 0x1072ec5f8>,
#  <__main__.DataSet at 0x1072ec630>,
#  <__main__.DataSet at 0x1072ec668>,
#  <__main__.DataSet at 0x1072ec6a0>,
#  <__main__.DataSet at 0x1072ec6d8>,
#  <__main__.DataSet at 0x1072ec710>,
#  <__main__.DataSet at 0x1072ec748>,
#  <__main__.DataSet at 0x1072ec780>,
#  <__main__.DataSet at 0x1072ec7b8>,
#  <__main__.DataSet at 0x1072ec7f0>,
#  <__main__.DataSet at 0x1072ec828>,
#  <__main__.DataSet at 0x1072ec860>,
#  <__main__.DataSet at 0x1072ec898>,
#  <__main__.DataSet at 0x1072ec8d0>,
#  <__main__.DataSet at 0x1072ec908>,
#  <__main__.DataSet at 0x1072ec940>,
#  <__main__.DataSet at 0x1072ec978>,
#  <__main__.DataSet at 0x1072ec9b0>,
#  <__main__.DataSet at 0x1072ec9e8>,
#  <__main__.DataSet at 0x1072eca20>,
#  <__main__.DataSet at 0x1072eca58>,
#  <__main__.DataSet at 0x1072eca90>,
#  <__main__.DataSet at 0x1072ecac8>,
#  <__main__.DataSet at 0x1072ecb00>,
#  <__main__.DataSet at 0x1072ecb38>,
#  <__main__.DataSet at 0x1072ecb70>,
#  <__main__.DataSet at 0x1072ecba8>,
#  <__main__.DataSet at 0x1072ecbe0>,
#  <__main__.DataSet at 0x1072ecc18>,
#  <__main__.DataSet at 0x1072ecc50>,
#  <__main__.DataSet at 0x1072ecc88>,
#  <__main__.DataSet at 0x1072eccc0>,
#  <__main__.DataSet at 0x1072eccf8>,
#  <__main__.DataSet at 0x1072ecd30>,
#  <__main__.DataSet at 0x1072ecd68>,
#  <__main__.DataSet at 0x1072ecda0>,
#  <__main__.DataSet at 0x1072ecdd8>,
#  <__main__.DataSet at 0x1072ece10>,
#  <__main__.DataSet at 0x1072ece48>,
#  <__main__.DataSet at 0x1072ece80>,
#  <__main__.DataSet at 0x1072eceb8>,
#  <__main__.DataSet at 0x1072ecef0>,
#  <__main__.DataSet at 0x1072ecf28>,
#  <__main__.DataSet at 0x1072ecf60>,
#  <__main__.DataSet at 0x1072ecf98>,
#  <__main__.DataSet at 0x1072ecfd0>,
#  <__main__.DataSet at 0x1072f1048>,
#  <__main__.DataSet at 0x1072f1080>,
#  <__main__.DataSet at 0x1072f10b8>,
#  <__main__.DataSet at 0x1072f10f0>,
#  <__main__.DataSet at 0x1072f1128>,
#  <__main__.DataSet at 0x1072f1160>,
#  <__main__.DataSet at 0x1072f1198>,
#  <__main__.DataSet at 0x1072f11d0>,
#  <__main__.DataSet at 0x1072f1208>,
#  <__main__.DataSet at 0x1072f1240>,
#  <__main__.DataSet at 0x1072f1278>,
#  <__main__.DataSet at 0x1072f12b0>,
#  <__main__.DataSet at 0x1072f12e8>,
#  <__main__.DataSet at 0x1072f1320>,
#  <__main__.DataSet at 0x1072f1358>,
#  <__main__.DataSet at 0x1072f1390>,
#  <__main__.DataSet at 0x1072f13c8>,
#  <__main__.DataSet at 0x1072f1400>,
#  <__main__.DataSet at 0x1072f1438>,
#  <__main__.DataSet at 0x1072f1470>,
#  <__main__.DataSet at 0x1072f14a8>,
#  <__main__.DataSet at 0x1072f14e0>,
#  <__main__.DataSet at 0x1072f1518>,
#  <__main__.DataSet at 0x1072f1550>,
#  <__main__.DataSet at 0x1072f1588>,
#  <__main__.DataSet at 0x1072f15c0>,
#  <__main__.DataSet at 0x1072f15f8>,
#  <__main__.DataSet at 0x1072f1630>,
#  <__main__.DataSet at 0x1072f1668>,
#  <__main__.DataSet at 0x1072f16a0>,
#  <__main__.DataSet at 0x1072f16d8>,
#  <__main__.DataSet at 0x1072f1710>,
#  <__main__.DataSet at 0x1072f1748>,
#  <__main__.DataSet at 0x1072f1780>,
#  <__main__.DataSet at 0x1072f17b8>,
#  <__main__.DataSet at 0x1072f17f0>,
#  <__main__.DataSet at 0x1072f1828>,
#  <__main__.DataSet at 0x1072f1860>,
#  <__main__.DataSet at 0x1072f1898>,
#  <__main__.DataSet at 0x1072f18d0>,
#  <__main__.DataSet at 0x1072f1908>,
#  <__main__.DataSet at 0x1072f1940>,
#  <__main__.DataSet at 0x1072f1978>,
#  <__main__.DataSet at 0x1072f19b0>,
#  <__main__.DataSet at 0x1072f19e8>,
#  <__main__.DataSet at 0x1072f1a20>,
#  <__main__.DataSet at 0x1072f1a58>,
#  <__main__.DataSet at 0x1072f1a90>,
#  <__main__.DataSet at 0x1072f1ac8>,
#  <__main__.DataSet at 0x1072f1b00>,
#  <__main__.DataSet at 0x1072f1b38>,
#  <__main__.DataSet at 0x1072f1b70>,
#  <__main__.DataSet at 0x1072f1ba8>,
#  <__main__.DataSet at 0x1072f1be0>,
#  <__main__.DataSet at 0x1072f1c18>,
#  <__main__.DataSet at 0x1072f1c50>,
#  <__main__.DataSet at 0x1072f1c88>,
#  <__main__.DataSet at 0x1072f1cc0>,
#  <__main__.DataSet at 0x1072f1cf8>,
#  <__main__.DataSet at 0x1072f1d30>,
#  <__main__.DataSet at 0x1072f1d68>,
#  <__main__.DataSet at 0x1072f1da0>,
#  <__main__.DataSet at 0x1072f1dd8>,
#  <__main__.DataSet at 0x1072f1e10>,
#  <__main__.DataSet at 0x1072f1e48>,
#  <__main__.DataSet at 0x1072f1e80>,
#  <__main__.DataSet at 0x1072f1eb8>,
#  <__main__.DataSet at 0x1072f1ef0>,
#  <__main__.DataSet at 0x1072f1f28>,
#  <__main__.DataSet at 0x1072f1f60>,
#  <__main__.DataSet at 0x1072f1f98>,
#  <__main__.DataSet at 0x1072f1fd0>,
#  <__main__.DataSet at 0x1072f7048>,
#  <__main__.DataSet at 0x1072f7080>,
#  <__main__.DataSet at 0x1072f70b8>,
#  <__main__.DataSet at 0x1072f70f0>,
#  <__main__.DataSet at 0x1072f7128>,
#  <__main__.DataSet at 0x1072f7160>,
#  <__main__.DataSet at 0x1072f7198>,
#  <__main__.DataSet at 0x1072f71d0>,
#  <__main__.DataSet at 0x1072f7208>,
#  <__main__.DataSet at 0x1072f7240>,
#  <__main__.DataSet at 0x1072f7278>,
#  <__main__.DataSet at 0x1072f72b0>,
#  <__main__.DataSet at 0x1072f72e8>,
#  <__main__.DataSet at 0x1072f7320>,
#  <__main__.DataSet at 0x1072f7358>,
#  <__main__.DataSet at 0x1072f7390>,
#  <__main__.DataSet at 0x1072f73c8>,
#  <__main__.DataSet at 0x1072f7400>,
#  <__main__.DataSet at 0x1072f7438>,
#  <__main__.DataSet at 0x1072f7470>,
#  <__main__.DataSet at 0x1072f74a8>,
#  <__main__.DataSet at 0x1072f74e0>,
#  <__main__.DataSet at 0x1072f7518>,
#  <__main__.DataSet at 0x1072f7550>,
#  <__main__.DataSet at 0x1072f7588>,
#  <__main__.DataSet at 0x1072f75c0>,
#  <__main__.DataSet at 0x1072f75f8>,
#  <__main__.DataSet at 0x1072f7630>,
#  <__main__.DataSet at 0x1072f7668>,
#  <__main__.DataSet at 0x1072f76a0>,
#  <__main__.DataSet at 0x1072f76d8>,
#  <__main__.DataSet at 0x1072f7710>,
#  <__main__.DataSet at 0x1072f7748>,
#  <__main__.DataSet at 0x1072f7780>,
#  <__main__.DataSet at 0x1072f77b8>,
#  <__main__.DataSet at 0x1072f77f0>,
#  <__main__.DataSet at 0x1072f7828>,
#  <__main__.DataSet at 0x1072f7860>,
#  <__main__.DataSet at 0x1072f7898>,
#  <__main__.DataSet at 0x1072f78d0>,
#  <__main__.DataSet at 0x1072f7908>,
#  <__main__.DataSet at 0x1072f7940>,
#  <__main__.DataSet at 0x1072f7978>,
#  <__main__.DataSet at 0x1072f79b0>,
#  <__main__.DataSet at 0x1072f79e8>,
#  <__main__.DataSet at 0x1072f7a20>,
#  <__main__.DataSet at 0x1072f7a58>,
#  <__main__.DataSet at 0x1072f7a90>,
#  <__main__.DataSet at 0x1072f7ac8>,
#  <__main__.DataSet at 0x1072f7b00>,
#  <__main__.DataSet at 0x1072f7b38>,
#  <__main__.DataSet at 0x1072f7b70>,
#  <__main__.DataSet at 0x1072f7ba8>,
#  <__main__.DataSet at 0x1072f7be0>,
#  <__main__.DataSet at 0x1072f7c18>,
#  <__main__.DataSet at 0x1072f7c50>,
#  <__main__.DataSet at 0x1072f7c88>,
#  <__main__.DataSet at 0x1072f7cc0>,
#  <__main__.DataSet at 0x1072f7cf8>,
#  <__main__.DataSet at 0x1072f7d30>,
#  <__main__.DataSet at 0x1072f7d68>,
#  <__main__.DataSet at 0x1072f7da0>,
#  <__main__.DataSet at 0x1072f7dd8>,
#  <__main__.DataSet at 0x1072f7e10>,
#  <__main__.DataSet at 0x1072f7e48>,
#  <__main__.DataSet at 0x1072f7e80>,
#  <__main__.DataSet at 0x1072f7eb8>,
#  <__main__.DataSet at 0x1072f7ef0>,
#  <__main__.DataSet at 0x1072f7f28>,
#  <__main__.DataSet at 0x1072f7f60>,
#  <__main__.DataSet at 0x1072f7f98>,
#  <__main__.DataSet at 0x1072f7fd0>,
#  <__main__.DataSet at 0x1072fb048>,
#  <__main__.DataSet at 0x1072fb080>,
#  <__main__.DataSet at 0x1072fb0b8>,
#  <__main__.DataSet at 0x1072fb0f0>,
#  <__main__.DataSet at 0x1072fb128>,
#  <__main__.DataSet at 0x1072fb160>,
#  <__main__.DataSet at 0x1072fb198>,
#  <__main__.DataSet at 0x1072fb1d0>,
#  <__main__.DataSet at 0x1072fb208>,
#  <__main__.DataSet at 0x1072fb240>,
#  <__main__.DataSet at 0x1072fb278>,
#  <__main__.DataSet at 0x1072fb2b0>,
#  <__main__.DataSet at 0x1072fb2e8>,
#  <__main__.DataSet at 0x1072fb320>,
#  <__main__.DataSet at 0x1072fb358>,
#  <__main__.DataSet at 0x1072fb390>,
#  <__main__.DataSet at 0x1072fb3c8>,
#  <__main__.DataSet at 0x1072fb400>,
#  <__main__.DataSet at 0x1072fb438>,
#  <__main__.DataSet at 0x1072fb470>,
#  <__main__.DataSet at 0x1072fb4a8>,
#  <__main__.DataSet at 0x1072fb4e0>,
#  <__main__.DataSet at 0x1072fb518>,
#  <__main__.DataSet at 0x1072fb550>,
#  <__main__.DataSet at 0x1072fb588>,
#  <__main__.DataSet at 0x1072fb5c0>,
#  <__main__.DataSet at 0x1072fb5f8>,
#  <__main__.DataSet at 0x1072fb630>,
#  <__main__.DataSet at 0x1072fb668>,
#  <__main__.DataSet at 0x1072fb6a0>,
#  <__main__.DataSet at 0x1072fb6d8>,
#  <__main__.DataSet at 0x1072fb710>,
#  <__main__.DataSet at 0x1072fb748>,
#  <__main__.DataSet at 0x1072fb780>,
#  <__main__.DataSet at 0x1072fb7b8>,
#  <__main__.DataSet at 0x1072fb7f0>,
#  <__main__.DataSet at 0x1072fb828>,
#  <__main__.DataSet at 0x1072fb860>,
#  <__main__.DataSet at 0x1072fb898>,
#  <__main__.DataSet at 0x1072fb8d0>,
#  <__main__.DataSet at 0x1072fb908>,
#  <__main__.DataSet at 0x1072fb940>,
#  <__main__.DataSet at 0x1072fb978>,
#  <__main__.DataSet at 0x1072fb9b0>,
#  <__main__.DataSet at 0x1072fb9e8>,
#  <__main__.DataSet at 0x1072fba20>,
#  <__main__.DataSet at 0x1072fba58>,
#  <__main__.DataSet at 0x1072fba90>,
#  <__main__.DataSet at 0x1072fbac8>,
#  <__main__.DataSet at 0x1072fbb00>,
#  <__main__.DataSet at 0x1072fbb38>,
#  <__main__.DataSet at 0x1072fbb70>,
#  <__main__.DataSet at 0x1072fbba8>,
#  <__main__.DataSet at 0x1072fbbe0>,
#  <__main__.DataSet at 0x1072fbc18>,
#  <__main__.DataSet at 0x1072fbc50>,
#  <__main__.DataSet at 0x1072fbc88>,
#  <__main__.DataSet at 0x1072fbcc0>,
#  <__main__.DataSet at 0x1072fbcf8>,
#  <__main__.DataSet at 0x1072fbd30>,
#  <__main__.DataSet at 0x1072fbd68>,
#  <__main__.DataSet at 0x1072fbda0>,
#  <__main__.DataSet at 0x1072fbdd8>,
#  <__main__.DataSet at 0x1072fbe10>,
#  <__main__.DataSet at 0x1072fbe48>,
#  <__main__.DataSet at 0x1072fbe80>,
#  <__main__.DataSet at 0x1072fbeb8>,
#  <__main__.DataSet at 0x1072fbef0>,
#  <__main__.DataSet at 0x1072fbf28>,
#  <__main__.DataSet at 0x1072fbf60>,
#  <__main__.DataSet at 0x1072fbf98>,
#  <__main__.DataSet at 0x1072fbfd0>,
#  <__main__.DataSet at 0x107301048>,
#  <__main__.DataSet at 0x107301080>,
#  <__main__.DataSet at 0x1073010b8>,
#  <__main__.DataSet at 0x1073010f0>,
#  <__main__.DataSet at 0x107301128>,
#  <__main__.DataSet at 0x107301160>,
#  <__main__.DataSet at 0x107301198>,
#  <__main__.DataSet at 0x1073011d0>,
#  <__main__.DataSet at 0x107301208>,
#  <__main__.DataSet at 0x107301240>,
#  <__main__.DataSet at 0x107301278>,
#  <__main__.DataSet at 0x1073012b0>,
#  <__main__.DataSet at 0x1073012e8>,
#  <__main__.DataSet at 0x107301320>,
#  <__main__.DataSet at 0x107301358>,
#  <__main__.DataSet at 0x107301390>,
#  <__main__.DataSet at 0x1073013c8>,
#  <__main__.DataSet at 0x107301400>,
#  <__main__.DataSet at 0x107301438>,
#  <__main__.DataSet at 0x107301470>,
#  <__main__.DataSet at 0x1073014a8>,
#  <__main__.DataSet at 0x1073014e0>,
#  <__main__.DataSet at 0x107301518>,
#  <__main__.DataSet at 0x107301550>,
#  <__main__.DataSet at 0x107301588>,
#  <__main__.DataSet at 0x1073015c0>,
#  <__main__.DataSet at 0x1073015f8>,
#  <__main__.DataSet at 0x107301630>,
#  <__main__.DataSet at 0x107301668>,
#  <__main__.DataSet at 0x1073016a0>,
#  <__main__.DataSet at 0x1073016d8>,
#  <__main__.DataSet at 0x107301710>,
#  <__main__.DataSet at 0x107301748>,
#  <__main__.DataSet at 0x107301780>,
#  <__main__.DataSet at 0x1073017b8>,
#  <__main__.DataSet at 0x1073017f0>,
#  <__main__.DataSet at 0x107301828>,
#  <__main__.DataSet at 0x107301860>,
#  <__main__.DataSet at 0x107301898>,
#  <__main__.DataSet at 0x1073018d0>,
#  <__main__.DataSet at 0x107301908>,
#  <__main__.DataSet at 0x107301940>,
#  <__main__.DataSet at 0x107301978>,
#  <__main__.DataSet at 0x1073019b0>,
#  <__main__.DataSet at 0x1073019e8>,
#  <__main__.DataSet at 0x107301a20>,
#  <__main__.DataSet at 0x107301a58>,
#  <__main__.DataSet at 0x107301a90>,
#  <__main__.DataSet at 0x107301ac8>,
#  <__main__.DataSet at 0x107301b00>,
#  <__main__.DataSet at 0x107301b38>,
#  <__main__.DataSet at 0x107301b70>,
#  <__main__.DataSet at 0x107301ba8>,
#  <__main__.DataSet at 0x107301be0>,
#  <__main__.DataSet at 0x107301c18>,
#  <__main__.DataSet at 0x107301c50>,
#  <__main__.DataSet at 0x107301c88>,
#  <__main__.DataSet at 0x107301cc0>,
#  <__main__.DataSet at 0x107301cf8>,
#  <__main__.DataSet at 0x107301d30>,
#  <__main__.DataSet at 0x107301d68>,
#  <__main__.DataSet at 0x107301da0>,
#  <__main__.DataSet at 0x107301dd8>,
#  <__main__.DataSet at 0x107301e10>,
#  <__main__.DataSet at 0x107301e48>,
#  <__main__.DataSet at 0x107301e80>,
#  <__main__.DataSet at 0x107301eb8>,
#  <__main__.DataSet at 0x107301ef0>,
#  <__main__.DataSet at 0x107301f28>,
#  <__main__.DataSet at 0x107301f60>,
#  <__main__.DataSet at 0x107301f98>,
#  <__main__.DataSet at 0x107301fd0>,
#  <__main__.DataSet at 0x107305048>,
#  <__main__.DataSet at 0x107305080>,
#  <__main__.DataSet at 0x1073050b8>,
#  <__main__.DataSet at 0x1073050f0>,
#  <__main__.DataSet at 0x107305128>,
#  <__main__.DataSet at 0x107305160>,
#  <__main__.DataSet at 0x107305198>,
#  <__main__.DataSet at 0x1073051d0>,
#  <__main__.DataSet at 0x107305208>,
#  <__main__.DataSet at 0x107305240>,
#  <__main__.DataSet at 0x107305278>,
#  <__main__.DataSet at 0x1073052b0>,
#  <__main__.DataSet at 0x1073052e8>,
#  <__main__.DataSet at 0x107305320>,
#  <__main__.DataSet at 0x107305358>,
#  <__main__.DataSet at 0x107305390>,
#  <__main__.DataSet at 0x1073053c8>,
#  <__main__.DataSet at 0x107305400>,
#  <__main__.DataSet at 0x107305438>,
#  <__main__.DataSet at 0x107305470>,
#  <__main__.DataSet at 0x1073054a8>,
#  <__main__.DataSet at 0x1073054e0>,
#  <__main__.DataSet at 0x107305518>,
#  <__main__.DataSet at 0x107305550>,
#  <__main__.DataSet at 0x107305588>,
#  <__main__.DataSet at 0x1073055c0>,
#  <__main__.DataSet at 0x1073055f8>,
#  <__main__.DataSet at 0x107305630>,
#  <__main__.DataSet at 0x107305668>,
#  <__main__.DataSet at 0x1073056a0>,
#  <__main__.DataSet at 0x1073056d8>,
#  <__main__.DataSet at 0x107305710>,
#  <__main__.DataSet at 0x107305748>,
#  <__main__.DataSet at 0x107305780>,
#  <__main__.DataSet at 0x1073057b8>,
#  <__main__.DataSet at 0x1073057f0>,
#  <__main__.DataSet at 0x107305828>,
#  <__main__.DataSet at 0x107305860>,
#  <__main__.DataSet at 0x107305898>,
#  <__main__.DataSet at 0x1073058d0>,
#  <__main__.DataSet at 0x107305908>,
#  <__main__.DataSet at 0x107305940>,
#  <__main__.DataSet at 0x107305978>,
#  <__main__.DataSet at 0x1073059b0>,
#  <__main__.DataSet at 0x1073059e8>,
#  <__main__.DataSet at 0x107305a20>,
#  <__main__.DataSet at 0x107305a58>,
#  <__main__.DataSet at 0x107305a90>,
#  <__main__.DataSet at 0x107305ac8>,
#  <__main__.DataSet at 0x107305b00>,
#  <__main__.DataSet at 0x107305b38>,
#  <__main__.DataSet at 0x107305b70>,
#  <__main__.DataSet at 0x107305ba8>,
#  <__main__.DataSet at 0x107305be0>,
#  <__main__.DataSet at 0x107305c18>,
#  <__main__.DataSet at 0x107305c50>,
#  <__main__.DataSet at 0x107305c88>,
#  <__main__.DataSet at 0x107305cc0>,
#  <__main__.DataSet at 0x107305cf8>,
#  <__main__.DataSet at 0x107305d30>,
#  <__main__.DataSet at 0x107305d68>,
#  <__main__.DataSet at 0x107305da0>,
#  <__main__.DataSet at 0x107305dd8>,
#  <__main__.DataSet at 0x107305e10>,
#  <__main__.DataSet at 0x107305e48>,
#  <__main__.DataSet at 0x107305e80>,
#  <__main__.DataSet at 0x107305eb8>,
#  <__main__.DataSet at 0x107305ef0>,
#  <__main__.DataSet at 0x107305f28>,
#  <__main__.DataSet at 0x107305f60>,
#  <__main__.DataSet at 0x107305f98>,
#  <__main__.DataSet at 0x107305fd0>,
#  <__main__.DataSet at 0x10730a048>,
#  <__main__.DataSet at 0x10730a080>,
#  <__main__.DataSet at 0x10730a0b8>,
#  <__main__.DataSet at 0x10730a0f0>,
#  <__main__.DataSet at 0x10730a128>,
#  <__main__.DataSet at 0x10730a160>,
#  <__main__.DataSet at 0x10730a198>,
#  <__main__.DataSet at 0x10730a1d0>,
#  <__main__.DataSet at 0x10730a208>,
#  <__main__.DataSet at 0x10730a240>,
#  <__main__.DataSet at 0x10730a278>,
#  <__main__.DataSet at 0x10730a2b0>,
#  <__main__.DataSet at 0x10730a2e8>,
#  <__main__.DataSet at 0x10730a320>,
#  <__main__.DataSet at 0x10730a358>,
#  <__main__.DataSet at 0x10730a390>,
#  <__main__.DataSet at 0x10730a3c8>,
#  <__main__.DataSet at 0x10730a400>,
#  <__main__.DataSet at 0x10730a438>,
#  <__main__.DataSet at 0x10730a470>,
#  <__main__.DataSet at 0x10730a4a8>,
#  <__main__.DataSet at 0x10730a4e0>,
#  <__main__.DataSet at 0x10730a518>,
#  <__main__.DataSet at 0x10730a550>,
#  <__main__.DataSet at 0x10730a588>,
#  <__main__.DataSet at 0x10730a5c0>,
#  <__main__.DataSet at 0x10730a5f8>,
#  <__main__.DataSet at 0x10730a630>,
#  <__main__.DataSet at 0x10730a668>,
#  <__main__.DataSet at 0x10730a6a0>,
#  <__main__.DataSet at 0x10730a6d8>,
#  <__main__.DataSet at 0x10730a710>,
#  <__main__.DataSet at 0x10730a748>,
#  <__main__.DataSet at 0x10730a780>,
#  <__main__.DataSet at 0x10730a7b8>,
#  <__main__.DataSet at 0x10730a7f0>,
#  <__main__.DataSet at 0x10730a828>,
#  <__main__.DataSet at 0x10730a860>,
#  <__main__.DataSet at 0x10730a898>,
#  <__main__.DataSet at 0x10730a8d0>,
#  <__main__.DataSet at 0x10730a908>,
#  <__main__.DataSet at 0x10730a940>,
#  <__main__.DataSet at 0x10730a978>,
#  <__main__.DataSet at 0x10730a9b0>,
#  <__main__.DataSet at 0x10730a9e8>,
#  <__main__.DataSet at 0x10730aa20>,
#  <__main__.DataSet at 0x10730aa58>,
#  <__main__.DataSet at 0x10730aa90>,
#  <__main__.DataSet at 0x10730aac8>,
#  <__main__.DataSet at 0x10730ab00>,
#  <__main__.DataSet at 0x10730ab38>,
#  <__main__.DataSet at 0x10730ab70>,
#  <__main__.DataSet at 0x10730aba8>,
#  <__main__.DataSet at 0x10730abe0>,
#  <__main__.DataSet at 0x10730ac18>,
#  <__main__.DataSet at 0x10730ac50>,
#  <__main__.DataSet at 0x10730ac88>,
#  <__main__.DataSet at 0x10730acc0>,
#  <__main__.DataSet at 0x10730acf8>,
#  <__main__.DataSet at 0x10730ad30>,
#  <__main__.DataSet at 0x10730ad68>,
#  <__main__.DataSet at 0x10730ada0>,
#  <__main__.DataSet at 0x10730add8>,
#  <__main__.DataSet at 0x10730ae10>,
#  <__main__.DataSet at 0x10730ae48>,
#  <__main__.DataSet at 0x10730ae80>,
#  <__main__.DataSet at 0x10730aeb8>,
#  <__main__.DataSet at 0x10730aef0>,
#  <__main__.DataSet at 0x10730af28>,
#  <__main__.DataSet at 0x10730af60>,
#  <__main__.DataSet at 0x10730af98>,
#  <__main__.DataSet at 0x10730afd0>,
#  <__main__.DataSet at 0x10730f048>,
#  <__main__.DataSet at 0x10730f080>,
#  <__main__.DataSet at 0x10730f0b8>,
#  <__main__.DataSet at 0x10730f0f0>,
#  <__main__.DataSet at 0x10730f128>,
#  <__main__.DataSet at 0x10730f160>,
#  <__main__.DataSet at 0x10730f198>,
#  <__main__.DataSet at 0x10730f1d0>,
#  <__main__.DataSet at 0x10730f208>,
#  <__main__.DataSet at 0x10730f240>,
#  <__main__.DataSet at 0x10730f278>,
#  <__main__.DataSet at 0x10730f2b0>,
#  <__main__.DataSet at 0x10730f2e8>,
#  <__main__.DataSet at 0x10730f320>,
#  <__main__.DataSet at 0x10730f358>,
#  <__main__.DataSet at 0x10730f390>,
#  <__main__.DataSet at 0x10730f3c8>,
#  <__main__.DataSet at 0x10730f400>,
#  <__main__.DataSet at 0x10730f438>,
#  <__main__.DataSet at 0x10730f470>,
#  <__main__.DataSet at 0x10730f4a8>,
#  <__main__.DataSet at 0x10730f4e0>,
#  <__main__.DataSet at 0x10730f518>,
#  <__main__.DataSet at 0x10730f550>,
#  <__main__.DataSet at 0x10730f588>,
#  <__main__.DataSet at 0x10730f5c0>,
#  <__main__.DataSet at 0x10730f5f8>,
#  <__main__.DataSet at 0x10730f630>,
#  <__main__.DataSet at 0x10730f668>,
#  <__main__.DataSet at 0x10730f6a0>,
#  <__main__.DataSet at 0x10730f6d8>,
#  <__main__.DataSet at 0x10730f710>,
#  <__main__.DataSet at 0x10730f748>,
#  <__main__.DataSet at 0x10730f780>,
#  <__main__.DataSet at 0x10730f7b8>,
#  <__main__.DataSet at 0x10730f7f0>,
#  <__main__.DataSet at 0x10730f828>,
#  <__main__.DataSet at 0x10730f860>,
#  <__main__.DataSet at 0x10730f898>,
#  <__main__.DataSet at 0x10730f8d0>,
#  <__main__.DataSet at 0x10730f908>,
#  <__main__.DataSet at 0x10730f940>,
#  <__main__.DataSet at 0x10730f978>,
#  <__main__.DataSet at 0x10730f9b0>,
#  <__main__.DataSet at 0x10730f9e8>,
#  <__main__.DataSet at 0x10730fa20>,
#  <__main__.DataSet at 0x10730fa58>,
#  <__main__.DataSet at 0x10730fa90>,
#  <__main__.DataSet at 0x10730fac8>,
#  <__main__.DataSet at 0x10730fb00>,
#  <__main__.DataSet at 0x10730fb38>,
#  <__main__.DataSet at 0x10730fb70>,
#  <__main__.DataSet at 0x10730fba8>,
#  <__main__.DataSet at 0x10730fbe0>,
#  <__main__.DataSet at 0x10730fc18>,
#  <__main__.DataSet at 0x10730fc50>,
#  <__main__.DataSet at 0x10730fc88>,
#  <__main__.DataSet at 0x10730fcc0>,
#  <__main__.DataSet at 0x10730fcf8>,
#  <__main__.DataSet at 0x10730fd30>,
#  <__main__.DataSet at 0x10730fd68>,
#  <__main__.DataSet at 0x10730fda0>,
#  <__main__.DataSet at 0x10730fdd8>,
#  <__main__.DataSet at 0x10730fe10>,
#  <__main__.DataSet at 0x10730fe48>,
#  <__main__.DataSet at 0x10730fe80>,
#  <__main__.DataSet at 0x10730feb8>,
#  <__main__.DataSet at 0x10730fef0>,
#  <__main__.DataSet at 0x10730ff28>,
#  <__main__.DataSet at 0x10730ff60>,
#  <__main__.DataSet at 0x10730ff98>,
#  <__main__.DataSet at 0x10730ffd0>,
#  <__main__.DataSet at 0x107314048>,
#  <__main__.DataSet at 0x107314080>,
#  <__main__.DataSet at 0x1073140b8>,
#  <__main__.DataSet at 0x1073140f0>,
#  <__main__.DataSet at 0x107314128>,
#  <__main__.DataSet at 0x107314160>,
#  <__main__.DataSet at 0x107314198>,
#  <__main__.DataSet at 0x1073141d0>,
#  <__main__.DataSet at 0x107314208>,
#  <__main__.DataSet at 0x107314240>,
#  <__main__.DataSet at 0x107314278>,
#  <__main__.DataSet at 0x1073142b0>,
#  <__main__.DataSet at 0x1073142e8>,
#  <__main__.DataSet at 0x107314320>,
#  <__main__.DataSet at 0x107314358>,
#  <__main__.DataSet at 0x107314390>,
#  <__main__.DataSet at 0x1073143c8>,
#  <__main__.DataSet at 0x107314400>,
#  <__main__.DataSet at 0x107314438>,
#  <__main__.DataSet at 0x107314470>,
#  <__main__.DataSet at 0x1073144a8>,
#  <__main__.DataSet at 0x1073144e0>,
#  <__main__.DataSet at 0x107314518>,
#  <__main__.DataSet at 0x107314550>,
#  <__main__.DataSet at 0x107314588>,
#  <__main__.DataSet at 0x1073145c0>,
#  <__main__.DataSet at 0x1073145f8>,
#  <__main__.DataSet at 0x107314630>,
#  <__main__.DataSet at 0x107314668>,
#  <__main__.DataSet at 0x1073146a0>,
#  <__main__.DataSet at 0x1073146d8>,
#  <__main__.DataSet at 0x107314710>,
#  <__main__.DataSet at 0x107314748>,
#  <__main__.DataSet at 0x107314780>,
#  <__main__.DataSet at 0x1073147b8>,
#  <__main__.DataSet at 0x1073147f0>,
#  <__main__.DataSet at 0x107314828>,
#  <__main__.DataSet at 0x107314860>,
#  <__main__.DataSet at 0x107314898>,
#  <__main__.DataSet at 0x1073148d0>,
#  <__main__.DataSet at 0x107314908>,
#  <__main__.DataSet at 0x107314940>,
#  <__main__.DataSet at 0x107314978>,
#  <__main__.DataSet at 0x1073149b0>,
#  <__main__.DataSet at 0x1073149e8>,
#  <__main__.DataSet at 0x107314a20>,
#  <__main__.DataSet at 0x107314a58>,
#  <__main__.DataSet at 0x107314a90>,
#  <__main__.DataSet at 0x107314ac8>,
#  <__main__.DataSet at 0x107314b00>,
#  <__main__.DataSet at 0x107314b38>,
#  <__main__.DataSet at 0x107314b70>,
#  <__main__.DataSet at 0x107314ba8>,
#  <__main__.DataSet at 0x107314be0>,
#  <__main__.DataSet at 0x107314c18>,
#  <__main__.DataSet at 0x107314c50>,
#  <__main__.DataSet at 0x107314c88>,
#  <__main__.DataSet at 0x107314cc0>,
#  <__main__.DataSet at 0x107314cf8>,
#  <__main__.DataSet at 0x107314d30>,
#  <__main__.DataSet at 0x107314d68>,
#  <__main__.DataSet at 0x107314da0>,
#  <__main__.DataSet at 0x107314dd8>,
#  <__main__.DataSet at 0x107314e10>,
#  <__main__.DataSet at 0x107314e48>,
#  <__main__.DataSet at 0x107314e80>,
#  <__main__.DataSet at 0x107314eb8>,
#  <__main__.DataSet at 0x107314ef0>,
#  <__main__.DataSet at 0x107314f28>,
#  <__main__.DataSet at 0x107314f60>,
#  <__main__.DataSet at 0x107314f98>,
#  <__main__.DataSet at 0x107314fd0>,
#  <__main__.DataSet at 0x10731a048>,
#  <__main__.DataSet at 0x10731a080>,
#  <__main__.DataSet at 0x10731a0b8>,
#  <__main__.DataSet at 0x10731a0f0>,
#  <__main__.DataSet at 0x10731a128>,
#  <__main__.DataSet at 0x10731a160>,
#  <__main__.DataSet at 0x10731a198>,
#  <__main__.DataSet at 0x10731a1d0>,
#  <__main__.DataSet at 0x10731a208>,
#  <__main__.DataSet at 0x10731a240>,
#  <__main__.DataSet at 0x10731a278>,
#  <__main__.DataSet at 0x10731a2b0>,
#  <__main__.DataSet at 0x10731a2e8>,
#  <__main__.DataSet at 0x10731a320>,
#  <__main__.DataSet at 0x10731a358>,
#  <__main__.DataSet at 0x10731a390>,
#  <__main__.DataSet at 0x10731a3c8>,
#  <__main__.DataSet at 0x10731a400>,
#  <__main__.DataSet at 0x10731a438>,
#  <__main__.DataSet at 0x10731a470>,
#  <__main__.DataSet at 0x10731a4a8>,
#  <__main__.DataSet at 0x10731a4e0>,
#  <__main__.DataSet at 0x10731a518>,
#  <__main__.DataSet at 0x10731a550>,
#  <__main__.DataSet at 0x10731a588>,
#  <__main__.DataSet at 0x10731a5c0>,
#  <__main__.DataSet at 0x10731a5f8>,
#  <__main__.DataSet at 0x10731a630>,
#  <__main__.DataSet at 0x10731a668>,
#  <__main__.DataSet at 0x10731a6a0>,
#  <__main__.DataSet at 0x10731a6d8>,
#  <__main__.DataSet at 0x10731a710>,
#  <__main__.DataSet at 0x10731a748>,
#  <__main__.DataSet at 0x10731a780>,
#  <__main__.DataSet at 0x10731a7b8>,
#  <__main__.DataSet at 0x10731a7f0>,
#  <__main__.DataSet at 0x10731a828>,
#  <__main__.DataSet at 0x10731a860>,
#  <__main__.DataSet at 0x10731a898>,
#  <__main__.DataSet at 0x10731a8d0>,
#  <__main__.DataSet at 0x10731a908>,
#  <__main__.DataSet at 0x10731a940>,
#  <__main__.DataSet at 0x10731a978>,
#  <__main__.DataSet at 0x10731a9b0>,
#  <__main__.DataSet at 0x10731a9e8>,
#  <__main__.DataSet at 0x10731aa20>,
#  <__main__.DataSet at 0x10731aa58>,
#  <__main__.DataSet at 0x10731aa90>,
#  <__main__.DataSet at 0x10731aac8>,
#  <__main__.DataSet at 0x10731ab00>,
#  <__main__.DataSet at 0x10731ab38>,
#  <__main__.DataSet at 0x10731ab70>,
#  <__main__.DataSet at 0x10731aba8>,
#  <__main__.DataSet at 0x10731abe0>,
#  <__main__.DataSet at 0x10731ac18>,
#  <__main__.DataSet at 0x10731ac50>,
#  <__main__.DataSet at 0x10731ac88>,
#  <__main__.DataSet at 0x10731acc0>,
#  <__main__.DataSet at 0x10731acf8>,
#  <__main__.DataSet at 0x10731ad30>,
#  <__main__.DataSet at 0x10731ad68>,
#  <__main__.DataSet at 0x10731ada0>,
#  <__main__.DataSet at 0x10731add8>,
#  ...]

# %%
#Create object of DBSCAN class
dbScan = DBSCAN()  
#Initialise dataSet  
dbScan.DB = all_pixels;  
#build clusters 
dbScan.DBSCAN()  

for i in range(len(dbScan.cluster)):  
    print('Cluster: ', i ) 
    for j in range(len(dbScan.cluster[i])):  
        print(dbScan.cluster[i][j].show())

# Writing new image
newImg = Image.new('RGB', (width,height))
pixels1 = newImg.load()
cnt = 0
cluster_tmp = []
for i in range (width):
    for j in range (height):
        for k in range(len(dbScan.cluster)):
            cluster_tmp.append([])
            for l in dbScan.cluster[k]:
                if(cpixels[cnt]==(l.r,l.g,l.b)):
                    cluster_tmp[k].append(DataSet(cpixels[cnt],i,j))
        cnt += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-41393df28bd5> in <module>()
#       4 dbScan.DB = all_pixels;
#       5 #build clusters
# ----> 6 dbScan.DBSCAN()
#       7
#       8 for i in range(len(dbScan.cluster)):
#
# <ipython-input-2-8ca569409af7> in DBSCAN(self)
#      28                                         self.cluster.append([])
#      29                                         self.cluster_inx = self.cluster_inx + 1
# ---> 30                                         self.check_neighbourhood(p_tmp, NeighborPts)
#      31
#      32         def check_neighbourhood(self, P, neighbor_points):
#
# <ipython-input-2-8ca569409af7> in check_neighbourhood(self, P, neighbor_points)
#      42                                 self.visit_cnt += 1
#      43
# ---> 44                                 NeighborPts1 = self.epsilon_neighbourhood(npoint_tmp)
#      45                                 if (len(NeighborPts1) >= self.MinPts):
#      46                                         for j in range(len(NeighborPts1)):
#
# <ipython-input-2-8ca569409af7> in epsilon_neighbourhood(self, P)
#      60                 for i in range(len(self.DB)):
#      61                         p_tmp = self.DB[i]
# ---> 62                         if (self.dist(P, p_tmp) <= self.epsilon and P.r != p_tmp.r and P.g != p_tmp.g and P.b != p_tmp.b):
#      63                                 pointInRegion.append(p_tmp)
#      64                 return pointInRegion #,points
#
# <ipython-input-2-8ca569409af7> in dist(self, p1, p2)
#      68                 dg = (p1.g - p2.g)
#      69                 db = (p1.b - p2.b)
# ---> 70                 a = sqrt(pow(dr,2) + pow(dg,2) + pow(db,2))
#      71                 return a/(255*sqrt(3))
#      72
#
# KeyboardInterrupt:

# %%
for i in range(len(dbScan.cluster)):
        dbScan.clusterCentroids.append(dbScan.mode(cluster_tmp[i]))

cnt = 0
for i in range (width):
    for j in range (height):
        for k in range(len(dbScan.cluster)):
            for l in dbScan.cluster[k]:
                if(cpixels[cnt]==(l.r,l.g,l.b)):
                    pixels1[i,j] = dbScan.clusterCentroids[k];
        cnt += 1

newImg.save("img1.png")
print("Number of clusters:",len(dbScan.clusterCentroids))
print("Noise:",len(dbScan.noise))
for i in cluster_tmp:
    if(cluster_tmp.index(i) == len(dbScan.clusterCentroids)):
        break
    xy = set([(j.x,j.y) for j in i])
    print("Cluster",cluster_tmp.index(i)+1,"\nLength of cluster:",len(i),"\nx-y coordinates:",xy)
